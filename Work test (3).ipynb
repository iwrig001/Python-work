# %% [markdown]
# ## Isaiah Wright notebook for Skills Assessment for the Research Analyst I position

# %% [markdown]
# ## Report Questions
#  • How many clients had 3 or more services in FY 2016-17?
#
#  • What was the average amount of services per client in FY 2016-17?
#
#
# • Create a chart that reflects the unique amount of clients who had jail services in FY 2016-17 broken down by Jail facility.  Note any findings.
#
#  • Create a table that reflects the number of IP Hospital services in FY 2016-17 broken down by month and hospital name.  Note any findings.
#
# • Note any other interesting findings from the data.

# %% [markdown]
# # Extracting the data from excel file

# %%
import pandas as pd

# %%
df = pd.read_excel (r'C:\Users\isaia\Downloads\Skills Assessment December 2020.xlsx', index_col=0, sheet_name=None)
print (df)
# Out:
# OrderedDict([('Instructions', Empty DataFrame
# Columns: []
# Index: [Answer as many of the below Report Questions in the "Report" tab that you can., Please show your work (formulas, pivot tables, etc.) and don’t be afraid to be creative with charts and graphs!, Create a dashboard using the program of your choice (Excel/PowerBi/Python/Etc..) to visually display your data., Compose a short narrative to explain your findings., Report Questions, • How many clients had 3 or more services in FY 2016-17?, • What was the average amount of services per client in FY 2016-17?, • Create a chart that reflects the unique amount of clients who had jail services in FY 2016-17 broken down by Jail facility.  Note any findings., • Create a table that reflects the number of IP Hospital services in FY 2016-17 broken down by month and hospital name.  Note any findings., • What percentage of unique clients that received IP Hospital services in FY 2016-17 were homeless?, • Note any other interesting findings from the data., Term Definitions, IP Hospital - Psychiatric Inpatient Hospital, PERT - Psychiatric Emergency Response Team, Jail - Mental Health Services Received in a Jail Facility]), ('Clients',            Gender Homeless Status
# Client ID
# 1            Male        Homeless
# 2            Male    Not Homeless
# 3          Female    Not Homeless
# 4          Female    Not Homeless
# 5            Male    Not Homeless
# 6            Male        Homeless
# 7            Male    Not Homeless
# 8            Male    Not Homeless
# 9          Female    Not Homeless
# 10           Male    Not Homeless
# 11           Male    Not Homeless
# 12           Male    Not Homeless
# 13         Female        Homeless
# 14           Male    Not Homeless
# 15           Male    Not Homeless
# 16           Male    Not Homeless
# 17         Female        Homeless
# 18           Male    Not Homeless
# 19           Male        Homeless
# 20         Female    Not Homeless
# 21           Male    Not Homeless
# 22           Male    Not Homeless
# 23         Female    Not Homeless
# 24         Female    Not Homeless
# 25           Male    Not Homeless
# 26         Female    Not Homeless
# 27           Male    Not Homeless
# 28         Female    Not Homeless
# 29           Male    Not Homeless
# 30           Male    Not Homeless
# ...           ...             ...
# 171          Male    Not Homeless
# 172        Female        Homeless
# 173        Female    Not Homeless
# 174          Male        Homeless
# 175        Female    Not Homeless
# 176          Male    Not Homeless
# 177          Male    Not Homeless
# 178          Male        Homeless
# 179        Female    Not Homeless
# 180          Male    Not Homeless
# 181          Male    Not Homeless
# 182        Female        Homeless
# 183          Male        Homeless
# 184          Male        Homeless
# 185          Male    Not Homeless
# 186          Male        Homeless
# 187          Male    Not Homeless
# 188        Female        Homeless
# 189          Male    Not Homeless
# 190        Female    Not Homeless
# 191          Male    Not Homeless
# 192        Female    Not Homeless
# 193        Female    Not Homeless
# 194          Male        Homeless
# 195          Male    Not Homeless
# 196          Male        Homeless
# 197          Male    Not Homeless
# 198        Female    Not Homeless
# 199          Male        Homeless
# 200          Male        Homeless
#
# [200 rows x 2 columns]), ('Client Services in FY 2016-17',            SubUnit ID Service Date  Unnamed: 3  Unnamed: 4
# Client ID
# 19               9502   2016-07-01         NaN         NaN
# 158              9503   2016-07-01         NaN         NaN
# 91               1141   2016-07-01         NaN         NaN
# 11               9507   2016-07-02         NaN         NaN
# 137              4131   2016-07-02         NaN         NaN
# 115              1522   2016-07-02         NaN         NaN
# 4                1211   2016-07-03         NaN         NaN
# 186              1211   2016-07-04         NaN         NaN
# 199              1531   2016-07-04         NaN         NaN
# 178              1522   2016-07-05         NaN         NaN
# 144              1541   2016-07-05         NaN         NaN
# 59               9501   2016-07-06         NaN        83.0
# 76               9503   2016-07-06         NaN         NaN
# 172              1511   2016-07-06         NaN         NaN
# 148              1211   2016-07-07         NaN         NaN
# 104              9502   2016-07-07         NaN         NaN
# 26               1141   2016-07-07         NaN         NaN
# 46               1522   2016-07-07         NaN         NaN
# 135              1541   2016-07-07         NaN         NaN
# 97               9505   2016-07-08         NaN         NaN
# 193              1511   2016-07-08         NaN         NaN
# 34               1511   2016-07-08         NaN         NaN
# 47               1522   2016-07-08         NaN         NaN
# 155              4131   2016-07-11         NaN         NaN
# 109              1211   2016-07-12         NaN         NaN
# 10               9502   2016-07-12         NaN         NaN
# 152              9503   2016-07-12         NaN         NaN
# 68               4131   2016-07-12         NaN         NaN
# 68               4132   2016-07-12         NaN         NaN
# 182              1211   2016-07-13         NaN         NaN
# ...               ...          ...         ...         ...
# 101              1541   2017-06-05         NaN         NaN
# 100              1211   2017-06-06         NaN         NaN
# 198              9504   2017-06-07         NaN         NaN
# 108              1511   2017-06-08         NaN         NaN
# 154              1511   2017-06-08         NaN         NaN
# 82               1541   2017-06-08         NaN         NaN
# 199              1541   2017-06-08         NaN         NaN
# 35               4131   2017-06-09         NaN         NaN
# 132              1211   2017-06-11         NaN         NaN
# 187              9503   2017-06-11         NaN         NaN
# 35               9505   2017-06-11         NaN         NaN
# 110              1511   2017-06-11         NaN         NaN
# 111              9502   2017-06-12         NaN         NaN
# 117              1511   2017-06-12         NaN         NaN
# 199              1141   2017-06-13         NaN         NaN
# 82               1141   2017-06-13         NaN         NaN
# 193              4132   2017-06-15         NaN         NaN
# 172              9502   2017-06-16         NaN         NaN
# 200              4131   2017-06-16         NaN         NaN
# 163              4131   2017-06-16         NaN         NaN
# 104              9503   2017-06-21         NaN         NaN
# 120              9503   2017-06-22         NaN         NaN
# 121              1541   2017-06-24         NaN         NaN
# 79               4131   2017-06-25         NaN         NaN
# 11               9508   2017-06-27         NaN         NaN
# 114              1522   2017-06-27         NaN         NaN
# 102              1522   2017-06-27         NaN         NaN
# 87               1541   2017-06-27         NaN         NaN
# 117              1511   2017-06-29         NaN         NaN
# 46               1541   2017-06-29         NaN         NaN
#
# [514 rows x 4 columns]), ('Service Descriptions',                      Service Facility Name Service Category         Region
# SubUnit ID
# 1211             CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central
# 9501                   ALVARADO PKWY INST       IP Hospital           East
# 9502                   PH BAYVIEW HOSPITAL      IP Hospital          South
# 9503               PH PARADISE VALLEY HOSP      IP Hospital          South
# 9504                   UCSD MEDICAL CENTER      IP Hospital        Central
# 9505                  SHARP GROSSMONT HOSP      IP Hospital           East
# 9506              SCRIPPS MERCY HEALTHCARE      IP Hospital        Central
# 9507                PALOMAR MEDICAL CENTER      IP Hospital   North Inland
# 9508                     TRI-CITY HOSPITAL      IP Hospital  North Coastal
# 9511             SHARP MESA VISTA HOSP (A)      IP Hospital  North Central
# 9515              OUT OF COUNTY HOSP ADULT      IP Hospital     No Address
# 4131                         CRF PERT MHSA             PERT  North Central
# 4132                        CRF PERT STAFF             PERT  North Central
# 1141               CO Adult Forensics Eval             Jail        Central
# 1511                     CO Las Colinas OP             Jail           East
# 1512               CO Las Colinas IP (PSU)             Jail           East
# 1521              CO Central Jail IP (PSU)             Jail        Central
# 1522                    CO Central Jail OP             Jail        Central
# 1531        CO Vista Detention Facility OP             Jail  North Coastal
# 1541         CO George Bailey Detention OP             Jail        Central), ('Report',                                                     Unnamed: 1  \
# NaN                                                        NaN
# NaN                                                        NaN
# Number of unique individuals who had services f...         NaN
#
#                                                                           Unnamed: 2  \
# NaN                                                                              NaN
# NaN                                                 Way of testing my wrok in Python
# Number of unique individuals who had services f...                               NaN
#
#                                                     Unnamed: 3  Unnamed: 4  \
# NaN                                                        NaN         NaN
# NaN                                                        NaN         NaN
# Number of unique individuals who had services f...         NaN         NaN
#
#                                                     Unnamed: 5
# NaN                                                        NaN
# NaN                                                        NaN
# Number of unique individuals who had services f...        83.0  )])

# %%
df_dict = {}
sheetname_list = ['Instructions', 'Clients', 'Client Services in FY 2016-17', 'Service Descriptions']
for sheet in sheetname_list:
    df_dict[sheet] = pd.read_excel(r'C:\Users\isaia\Downloads\Skills Assessment December 2020.xlsx', index_col=0, sheet_name=sheet)

# %%
df_dict
# Out:
# {'Instructions': Empty DataFrame
#  Columns: []
#  Index: [Answer as many of the below Report Questions in the "Report" tab that you can., Please show your work (formulas, pivot tables, etc.) and don’t be afraid to be creative with charts and graphs!, Create a dashboard using the program of your choice (Excel/PowerBi/Python/Etc..) to visually display your data., Compose a short narrative to explain your findings., Report Questions, • How many clients had 3 or more services in FY 2016-17?, • What was the average amount of services per client in FY 2016-17?, • Create a chart that reflects the unique amount of clients who had jail services in FY 2016-17 broken down by Jail facility.  Note any findings., • Create a table that reflects the number of IP Hospital services in FY 2016-17 broken down by month and hospital name.  Note any findings., • What percentage of unique clients that received IP Hospital services in FY 2016-17 were homeless?, • Note any other interesting findings from the data., Term Definitions, IP Hospital - Psychiatric Inpatient Hospital, PERT - Psychiatric Emergency Response Team, Jail - Mental Health Services Received in a Jail Facility],
#  'Clients':            Gender Homeless Status
#  Client ID
#  1            Male        Homeless
#  2            Male    Not Homeless
#  3          Female    Not Homeless
#  4          Female    Not Homeless
#  5            Male    Not Homeless
#  6            Male        Homeless
#  7            Male    Not Homeless
#  8            Male    Not Homeless
#  9          Female    Not Homeless
#  10           Male    Not Homeless
#  11           Male    Not Homeless
#  12           Male    Not Homeless
#  13         Female        Homeless
#  14           Male    Not Homeless
#  15           Male    Not Homeless
#  16           Male    Not Homeless
#  17         Female        Homeless
#  18           Male    Not Homeless
#  19           Male        Homeless
#  20         Female    Not Homeless
#  21           Male    Not Homeless
#  22           Male    Not Homeless
#  23         Female    Not Homeless
#  24         Female    Not Homeless
#  25           Male    Not Homeless
#  26         Female    Not Homeless
#  27           Male    Not Homeless
#  28         Female    Not Homeless
#  29           Male    Not Homeless
#  30           Male    Not Homeless
#  ...           ...             ...
#  171          Male    Not Homeless
#  172        Female        Homeless
#  173        Female    Not Homeless
#  174          Male        Homeless
#  175        Female    Not Homeless
#  176          Male    Not Homeless
#  177          Male    Not Homeless
#  178          Male        Homeless
#  179        Female    Not Homeless
#  180          Male    Not Homeless
#  181          Male    Not Homeless
#  182        Female        Homeless
#  183          Male        Homeless
#  184          Male        Homeless
#  185          Male    Not Homeless
#  186          Male        Homeless
#  187          Male    Not Homeless
#  188        Female        Homeless
#  189          Male    Not Homeless
#  190        Female    Not Homeless
#  191          Male    Not Homeless
#  192        Female    Not Homeless
#  193        Female    Not Homeless
#  194          Male        Homeless
#  195          Male    Not Homeless
#  196          Male        Homeless
#  197          Male    Not Homeless
#  198        Female    Not Homeless
#  199          Male        Homeless
#  200          Male        Homeless
#
#  [200 rows x 2 columns],
#  'Client Services in FY 2016-17':            SubUnit ID Service Date  Unnamed: 3  Unnamed: 4
#  Client ID
#  19               9502   2016-07-01         NaN         NaN
#  158              9503   2016-07-01         NaN         NaN
#  91               1141   2016-07-01         NaN         NaN
#  11               9507   2016-07-02         NaN         NaN
#  137              4131   2016-07-02         NaN         NaN
#  115              1522   2016-07-02         NaN         NaN
#  4                1211   2016-07-03         NaN         NaN
#  186              1211   2016-07-04         NaN         NaN
#  199              1531   2016-07-04         NaN         NaN
#  178              1522   2016-07-05         NaN         NaN
#  144              1541   2016-07-05         NaN         NaN
#  59               9501   2016-07-06         NaN        83.0
#  76               9503   2016-07-06         NaN         NaN
#  172              1511   2016-07-06         NaN         NaN
#  148              1211   2016-07-07         NaN         NaN
#  104              9502   2016-07-07         NaN         NaN
#  26               1141   2016-07-07         NaN         NaN
#  46               1522   2016-07-07         NaN         NaN
#  135              1541   2016-07-07         NaN         NaN
#  97               9505   2016-07-08         NaN         NaN
#  193              1511   2016-07-08         NaN         NaN
#  34               1511   2016-07-08         NaN         NaN
#  47               1522   2016-07-08         NaN         NaN
#  155              4131   2016-07-11         NaN         NaN
#  109              1211   2016-07-12         NaN         NaN
#  10               9502   2016-07-12         NaN         NaN
#  152              9503   2016-07-12         NaN         NaN
#  68               4131   2016-07-12         NaN         NaN
#  68               4132   2016-07-12         NaN         NaN
#  182              1211   2016-07-13         NaN         NaN
#  ...               ...          ...         ...         ...
#  101              1541   2017-06-05         NaN         NaN
#  100              1211   2017-06-06         NaN         NaN
#  198              9504   2017-06-07         NaN         NaN
#  108              1511   2017-06-08         NaN         NaN
#  154              1511   2017-06-08         NaN         NaN
#  82               1541   2017-06-08         NaN         NaN
#  199              1541   2017-06-08         NaN         NaN
#  35               4131   2017-06-09         NaN         NaN
#  132              1211   2017-06-11         NaN         NaN
#  187              9503   2017-06-11         NaN         NaN
#  35               9505   2017-06-11         NaN         NaN
#  110              1511   2017-06-11         NaN         NaN
#  111              9502   2017-06-12         NaN         NaN
#  117              1511   2017-06-12         NaN         NaN
#  199              1141   2017-06-13         NaN         NaN
#  82               1141   2017-06-13         NaN         NaN
#  193              4132   2017-06-15         NaN         NaN
#  172              9502   2017-06-16         NaN         NaN
#  200              4131   2017-06-16         NaN         NaN
#  163              4131   2017-06-16         NaN         NaN
#  104              9503   2017-06-21         NaN         NaN
#  120              9503   2017-06-22         NaN         NaN
#  121              1541   2017-06-24         NaN         NaN
#  79               4131   2017-06-25         NaN         NaN
#  11               9508   2017-06-27         NaN         NaN
#  114              1522   2017-06-27         NaN         NaN
#  102              1522   2017-06-27         NaN         NaN
#  87               1541   2017-06-27         NaN         NaN
#  117              1511   2017-06-29         NaN         NaN
#  46               1541   2017-06-29         NaN         NaN
#
#  [514 rows x 4 columns],
#  'Service Descriptions':                      Service Facility Name Service Category         Region
#  SubUnit ID
#  1211             CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central
#  9501                   ALVARADO PKWY INST       IP Hospital           East
#  9502                   PH BAYVIEW HOSPITAL      IP Hospital          South
#  9503               PH PARADISE VALLEY HOSP      IP Hospital          South
#  9504                   UCSD MEDICAL CENTER      IP Hospital        Central
#  9505                  SHARP GROSSMONT HOSP      IP Hospital           East
#  9506              SCRIPPS MERCY HEALTHCARE      IP Hospital        Central
#  9507                PALOMAR MEDICAL CENTER      IP Hospital   North Inland
#  9508                     TRI-CITY HOSPITAL      IP Hospital  North Coastal
#  9511             SHARP MESA VISTA HOSP (A)      IP Hospital  North Central
#  9515              OUT OF COUNTY HOSP ADULT      IP Hospital     No Address
#  4131                         CRF PERT MHSA             PERT  North Central
#  4132                        CRF PERT STAFF             PERT  North Central
#  1141               CO Adult Forensics Eval             Jail        Central
#  1511                     CO Las Colinas OP             Jail           East
#  1512               CO Las Colinas IP (PSU)             Jail           East
#  1521              CO Central Jail IP (PSU)             Jail        Central
#  1522                    CO Central Jail OP             Jail        Central
#  1531        CO Vista Detention Facility OP             Jail  North Coastal
#  1541         CO George Bailey Detention OP             Jail        Central}

# %%
import numpy as np

# %%
df_dict['Client Services in FY 2016-17'] #checking to make sure I can access the various sheets through dictionary command
# Out:
#            SubUnit ID Service Date  Unnamed: 3  Unnamed: 4
# Client ID
# 19               9502   2016-07-01         NaN         NaN
# 158              9503   2016-07-01         NaN         NaN
# 91               1141   2016-07-01         NaN         NaN
# 11               9507   2016-07-02         NaN         NaN
# 137              4131   2016-07-02         NaN         NaN
# 115              1522   2016-07-02         NaN         NaN
# 4                1211   2016-07-03         NaN         NaN
# 186              1211   2016-07-04         NaN         NaN
# 199              1531   2016-07-04         NaN         NaN
# 178              1522   2016-07-05         NaN         NaN
# 144              1541   2016-07-05         NaN         NaN
# 59               9501   2016-07-06         NaN        83.0
# 76               9503   2016-07-06         NaN         NaN
# 172              1511   2016-07-06         NaN         NaN
# 148              1211   2016-07-07         NaN         NaN
# 104              9502   2016-07-07         NaN         NaN
# 26               1141   2016-07-07         NaN         NaN
# 46               1522   2016-07-07         NaN         NaN
# 135              1541   2016-07-07         NaN         NaN
# 97               9505   2016-07-08         NaN         NaN
# 193              1511   2016-07-08         NaN         NaN
# 34               1511   2016-07-08         NaN         NaN
# 47               1522   2016-07-08         NaN         NaN
# 155              4131   2016-07-11         NaN         NaN
# 109              1211   2016-07-12         NaN         NaN
# 10               9502   2016-07-12         NaN         NaN
# 152              9503   2016-07-12         NaN         NaN
# 68               4131   2016-07-12         NaN         NaN
# 68               4132   2016-07-12         NaN         NaN
# 182              1211   2016-07-13         NaN         NaN
# ...               ...          ...         ...         ...
# 101              1541   2017-06-05         NaN         NaN
# 100              1211   2017-06-06         NaN         NaN
# 198              9504   2017-06-07         NaN         NaN
# 108              1511   2017-06-08         NaN         NaN
# 154              1511   2017-06-08         NaN         NaN
# 82               1541   2017-06-08         NaN         NaN
# 199              1541   2017-06-08         NaN         NaN
# 35               4131   2017-06-09         NaN         NaN
# 132              1211   2017-06-11         NaN         NaN
# 187              9503   2017-06-11         NaN         NaN
# 35               9505   2017-06-11         NaN         NaN
# 110              1511   2017-06-11         NaN         NaN
# 111              9502   2017-06-12         NaN         NaN
# 117              1511   2017-06-12         NaN         NaN
# 199              1141   2017-06-13         NaN         NaN
# 82               1141   2017-06-13         NaN         NaN
# 193              4132   2017-06-15         NaN         NaN
# 172              9502   2017-06-16         NaN         NaN
# 200              4131   2017-06-16         NaN         NaN
# 163              4131   2017-06-16         NaN         NaN
# 104              9503   2017-06-21         NaN         NaN
# 120              9503   2017-06-22         NaN         NaN
# 121              1541   2017-06-24         NaN         NaN
# 79               4131   2017-06-25         NaN         NaN
# 11               9508   2017-06-27         NaN         NaN
# 114              1522   2017-06-27         NaN         NaN
# 102              1522   2017-06-27         NaN         NaN
# 87               1541   2017-06-27         NaN         NaN
# 117              1511   2017-06-29         NaN         NaN
# 46               1541   2017-06-29         NaN         NaN
#
# [514 rows x 4 columns]

# %%
df_dict['Instructions']
# Out:
# Empty DataFrame
# Columns: []
# Index: [Answer as many of the below Report Questions in the "Report" tab that you can., Please show your work (formulas, pivot tables, etc.) and don’t be afraid to be creative with charts and graphs!, Create a dashboard using the program of your choice (Excel/PowerBi/Python/Etc..) to visually display your data., Compose a short narrative to explain your findings., Report Questions, • How many clients had 3 or more services in FY 2016-17?, • What was the average amount of services per client in FY 2016-17?, • Create a chart that reflects the unique amount of clients who had jail services in FY 2016-17 broken down by Jail facility.  Note any findings., • Create a table that reflects the number of IP Hospital services in FY 2016-17 broken down by month and hospital name.  Note any findings., • What percentage of unique clients that received IP Hospital services in FY 2016-17 were homeless?, • Note any other interesting findings from the data., Term Definitions, IP Hospital - Psychiatric Inpatient Hospital, PERT - Psychiatric Emergency Response Team, Jail - Mental Health Services Received in a Jail Facility]

# %%
client = df_dict['Client Services in FY 2016-17'] #defining the client services sheet as a pandas dataframe for use

# %%
client
# Out:
#            SubUnit ID Service Date  Unnamed: 3  Unnamed: 4
# Client ID
# 19               9502   2016-07-01         NaN         NaN
# 158              9503   2016-07-01         NaN         NaN
# 91               1141   2016-07-01         NaN         NaN
# 11               9507   2016-07-02         NaN         NaN
# 137              4131   2016-07-02         NaN         NaN
# 115              1522   2016-07-02         NaN         NaN
# 4                1211   2016-07-03         NaN         NaN
# 186              1211   2016-07-04         NaN         NaN
# 199              1531   2016-07-04         NaN         NaN
# 178              1522   2016-07-05         NaN         NaN
# 144              1541   2016-07-05         NaN         NaN
# 59               9501   2016-07-06         NaN        83.0
# 76               9503   2016-07-06         NaN         NaN
# 172              1511   2016-07-06         NaN         NaN
# 148              1211   2016-07-07         NaN         NaN
# 104              9502   2016-07-07         NaN         NaN
# 26               1141   2016-07-07         NaN         NaN
# 46               1522   2016-07-07         NaN         NaN
# 135              1541   2016-07-07         NaN         NaN
# 97               9505   2016-07-08         NaN         NaN
# 193              1511   2016-07-08         NaN         NaN
# 34               1511   2016-07-08         NaN         NaN
# 47               1522   2016-07-08         NaN         NaN
# 155              4131   2016-07-11         NaN         NaN
# 109              1211   2016-07-12         NaN         NaN
# 10               9502   2016-07-12         NaN         NaN
# 152              9503   2016-07-12         NaN         NaN
# 68               4131   2016-07-12         NaN         NaN
# 68               4132   2016-07-12         NaN         NaN
# 182              1211   2016-07-13         NaN         NaN
# ...               ...          ...         ...         ...
# 101              1541   2017-06-05         NaN         NaN
# 100              1211   2017-06-06         NaN         NaN
# 198              9504   2017-06-07         NaN         NaN
# 108              1511   2017-06-08         NaN         NaN
# 154              1511   2017-06-08         NaN         NaN
# 82               1541   2017-06-08         NaN         NaN
# 199              1541   2017-06-08         NaN         NaN
# 35               4131   2017-06-09         NaN         NaN
# 132              1211   2017-06-11         NaN         NaN
# 187              9503   2017-06-11         NaN         NaN
# 35               9505   2017-06-11         NaN         NaN
# 110              1511   2017-06-11         NaN         NaN
# 111              9502   2017-06-12         NaN         NaN
# 117              1511   2017-06-12         NaN         NaN
# 199              1141   2017-06-13         NaN         NaN
# 82               1141   2017-06-13         NaN         NaN
# 193              4132   2017-06-15         NaN         NaN
# 172              9502   2017-06-16         NaN         NaN
# 200              4131   2017-06-16         NaN         NaN
# 163              4131   2017-06-16         NaN         NaN
# 104              9503   2017-06-21         NaN         NaN
# 120              9503   2017-06-22         NaN         NaN
# 121              1541   2017-06-24         NaN         NaN
# 79               4131   2017-06-25         NaN         NaN
# 11               9508   2017-06-27         NaN         NaN
# 114              1522   2017-06-27         NaN         NaN
# 102              1522   2017-06-27         NaN         NaN
# 87               1541   2017-06-27         NaN         NaN
# 117              1511   2017-06-29         NaN         NaN
# 46               1541   2017-06-29         NaN         NaN
#
# [514 rows x 4 columns]

# %%
client= client.reset_index() #creating a new index so that I can use the CLient ID variable

# %%
client
# Out:
#      Client ID  SubUnit ID Service Date  Unnamed: 3  Unnamed: 4
# 0           19        9502   2016-07-01         NaN         NaN
# 1          158        9503   2016-07-01         NaN         NaN
# 2           91        1141   2016-07-01         NaN         NaN
# 3           11        9507   2016-07-02         NaN         NaN
# 4          137        4131   2016-07-02         NaN         NaN
# 5          115        1522   2016-07-02         NaN         NaN
# 6            4        1211   2016-07-03         NaN         NaN
# 7          186        1211   2016-07-04         NaN         NaN
# 8          199        1531   2016-07-04         NaN         NaN
# 9          178        1522   2016-07-05         NaN         NaN
# 10         144        1541   2016-07-05         NaN         NaN
# 11          59        9501   2016-07-06         NaN        83.0
# 12          76        9503   2016-07-06         NaN         NaN
# 13         172        1511   2016-07-06         NaN         NaN
# 14         148        1211   2016-07-07         NaN         NaN
# 15         104        9502   2016-07-07         NaN         NaN
# 16          26        1141   2016-07-07         NaN         NaN
# 17          46        1522   2016-07-07         NaN         NaN
# 18         135        1541   2016-07-07         NaN         NaN
# 19          97        9505   2016-07-08         NaN         NaN
# 20         193        1511   2016-07-08         NaN         NaN
# 21          34        1511   2016-07-08         NaN         NaN
# 22          47        1522   2016-07-08         NaN         NaN
# 23         155        4131   2016-07-11         NaN         NaN
# 24         109        1211   2016-07-12         NaN         NaN
# 25          10        9502   2016-07-12         NaN         NaN
# 26         152        9503   2016-07-12         NaN         NaN
# 27          68        4131   2016-07-12         NaN         NaN
# 28          68        4132   2016-07-12         NaN         NaN
# 29         182        1211   2016-07-13         NaN         NaN
# ..         ...         ...          ...         ...         ...
# 484        101        1541   2017-06-05         NaN         NaN
# 485        100        1211   2017-06-06         NaN         NaN
# 486        198        9504   2017-06-07         NaN         NaN
# 487        108        1511   2017-06-08         NaN         NaN
# 488        154        1511   2017-06-08         NaN         NaN
# 489         82        1541   2017-06-08         NaN         NaN
# 490        199        1541   2017-06-08         NaN         NaN
# 491         35        4131   2017-06-09         NaN         NaN
# 492        132        1211   2017-06-11         NaN         NaN
# 493        187        9503   2017-06-11         NaN         NaN
# 494         35        9505   2017-06-11         NaN         NaN
# 495        110        1511   2017-06-11         NaN         NaN
# 496        111        9502   2017-06-12         NaN         NaN
# 497        117        1511   2017-06-12         NaN         NaN
# 498        199        1141   2017-06-13         NaN         NaN
# 499         82        1141   2017-06-13         NaN         NaN
# 500        193        4132   2017-06-15         NaN         NaN
# 501        172        9502   2017-06-16         NaN         NaN
# 502        200        4131   2017-06-16         NaN         NaN
# 503        163        4131   2017-06-16         NaN         NaN
# 504        104        9503   2017-06-21         NaN         NaN
# 505        120        9503   2017-06-22         NaN         NaN
# 506        121        1541   2017-06-24         NaN         NaN
# 507         79        4131   2017-06-25         NaN         NaN
# 508         11        9508   2017-06-27         NaN         NaN
# 509        114        1522   2017-06-27         NaN         NaN
# 510        102        1522   2017-06-27         NaN         NaN
# 511         87        1541   2017-06-27         NaN         NaN
# 512        117        1511   2017-06-29         NaN         NaN
# 513         46        1541   2017-06-29         NaN         NaN
#
# [514 rows x 5 columns]

# %%
client.groupby('Client ID').size() #I need to be able to print this, the people have occur more than 3 times
# Out:
# Client ID
# 1       4
# 2       1
# 3       4
# 4       2
# 5       1
# 6       1
# 7       6
# 8       1
# 9       3
# 10     12
# 11     10
# 12      2
# 13      1
# 14      3
# 15      1
# 16      1
# 17      1
# 18      1
# 19      2
# 20      2
# 21      1
# 22      1
# 23      3
# 24      1
# 25      3
# 26      1
# 27      1
# 28      1
# 29      3
# 30      3
#        ..
# 171     1
# 172    13
# 173     1
# 174     3
# 175     1
# 176     2
# 177     2
# 178     4
# 179     1
# 180     1
# 181     1
# 182     3
# 183     3
# 184     3
# 185     6
# 186     7
# 187    10
# 188     7
# 189     2
# 190     1
# 191     1
# 192     1
# 193     2
# 194     4
# 195     1
# 196     1
# 197     3
# 198     1
# 199    10
# 200     3
# Length: 200, dtype: int64

# %%
client['Client ID']=client['Client ID'].astype(str) #converting Client ID to a string or object so that I can manipulate it

# %%
client.head
# Out:
# <bound method NDFrame.head of     Client ID  SubUnit ID Service Date  Unnamed: 3  Unnamed: 4
# 0          19        9502   2016-07-01         NaN         NaN
# 1         158        9503   2016-07-01         NaN         NaN
# 2          91        1141   2016-07-01         NaN         NaN
# 3          11        9507   2016-07-02         NaN         NaN
# 4         137        4131   2016-07-02         NaN         NaN
# 5         115        1522   2016-07-02         NaN         NaN
# 6           4        1211   2016-07-03         NaN         NaN
# 7         186        1211   2016-07-04         NaN         NaN
# 8         199        1531   2016-07-04         NaN         NaN
# 9         178        1522   2016-07-05         NaN         NaN
# 10        144        1541   2016-07-05         NaN         NaN
# 11         59        9501   2016-07-06         NaN        83.0
# 12         76        9503   2016-07-06         NaN         NaN
# 13        172        1511   2016-07-06         NaN         NaN
# 14        148        1211   2016-07-07         NaN         NaN
# 15        104        9502   2016-07-07         NaN         NaN
# 16         26        1141   2016-07-07         NaN         NaN
# 17         46        1522   2016-07-07         NaN         NaN
# 18        135        1541   2016-07-07         NaN         NaN
# 19         97        9505   2016-07-08         NaN         NaN
# 20        193        1511   2016-07-08         NaN         NaN
# 21         34        1511   2016-07-08         NaN         NaN
# 22         47        1522   2016-07-08         NaN         NaN
# 23        155        4131   2016-07-11         NaN         NaN
# 24        109        1211   2016-07-12         NaN         NaN
# 25         10        9502   2016-07-12         NaN         NaN
# 26        152        9503   2016-07-12         NaN         NaN
# 27         68        4131   2016-07-12         NaN         NaN
# 28         68        4132   2016-07-12         NaN         NaN
# 29        182        1211   2016-07-13         NaN         NaN
# ..        ...         ...          ...         ...         ...
# 484       101        1541   2017-06-05         NaN         NaN
# 485       100        1211   2017-06-06         NaN         NaN
# 486       198        9504   2017-06-07         NaN         NaN
# 487       108        1511   2017-06-08         NaN         NaN
# 488       154        1511   2017-06-08         NaN         NaN
# 489        82        1541   2017-06-08         NaN         NaN
# 490       199        1541   2017-06-08         NaN         NaN
# 491        35        4131   2017-06-09         NaN         NaN
# 492       132        1211   2017-06-11         NaN         NaN
# 493       187        9503   2017-06-11         NaN         NaN
# 494        35        9505   2017-06-11         NaN         NaN
# 495       110        1511   2017-06-11         NaN         NaN
# 496       111        9502   2017-06-12         NaN         NaN
# 497       117        1511   2017-06-12         NaN         NaN
# 498       199        1141   2017-06-13         NaN         NaN
# 499        82        1141   2017-06-13         NaN         NaN
# 500       193        4132   2017-06-15         NaN         NaN
# 501       172        9502   2017-06-16         NaN         NaN
# 502       200        4131   2017-06-16         NaN         NaN
# 503       163        4131   2017-06-16         NaN         NaN
# 504       104        9503   2017-06-21         NaN         NaN
# 505       120        9503   2017-06-22         NaN         NaN
# 506       121        1541   2017-06-24         NaN         NaN
# 507        79        4131   2017-06-25         NaN         NaN
# 508        11        9508   2017-06-27         NaN         NaN
# 509       114        1522   2017-06-27         NaN         NaN
# 510       102        1522   2017-06-27         NaN         NaN
# 511        87        1541   2017-06-27         NaN         NaN
# 512       117        1511   2017-06-29         NaN         NaN
# 513        46        1541   2017-06-29         NaN         NaN
#
# [514 rows x 5 columns]>

# %%
client['Client ID'].dtype #checking data type
# Out:
# dtype('O')

# %% [markdown]
# ## Addressing questions 1 and 2 from the instructions

# %%
S=client['Client ID'].value_counts() #counting how many occurences each patient has 
S
# Out:
# 104    15
# 172    13
# 10     12
# 11     10
# 199    10
# 187    10
# 41      9
# 68      9
# 143     9
# 100     8
# 111     8
# 186     7
# 34      7
# 188     7
# 130     6
# 7       6
# 88      6
# 120     6
# 46      6
# 82      6
# 185     6
# 45      5
# 122     5
# 162     5
# 101     5
# 157     5
# 85      5
# 152     4
# 163     4
# 129     4
#        ..
# 148     1
# 132     1
# 126     1
# 2       1
# 8       1
# 16      1
# 175     1
# 55      1
# 191     1
# 36      1
# 26      1
# 93      1
# 131     1
# 95      1
# 90      1
# 37      1
# 142     1
# 140     1
# 171     1
# 59      1
# 6       1
# 102     1
# 160     1
# 166     1
# 33      1
# 43      1
# 13      1
# 21      1
# 136     1
# 149     1
# Name: Client ID, Length: 200, dtype: int64

# %% [markdown]
# # Question 1 answer

# %%
print (S[S>2]) #identifying those who went for a service 3 or more times, found to be 66 out of 200 patients who had services 3 or more
# Out:
# 104    15
# 172    13
# 10     12
# 11     10
# 199    10
# 187    10
# 41      9
# 68      9
# 143     9
# 100     8
# 111     8
# 186     7
# 34      7
# 188     7
# 130     6
# 7       6
# 88      6
# 120     6
# 46      6
# 82      6
# 185     6
# 45      5
# 122     5
# 162     5
# 101     5
# 157     5
# 85      5
# 152     4
# 163     4
# 129     4
#        ..
# 194     4
# 87      4
# 47      4
# 1       4
# 170     4
# 74      4
# 73      3
# 118     3
# 91      3
# 86      3
# 184     3
# 197     3
# 139     3
# 9       3
# 182     3
# 183     3
# 144     3
# 159     3
# 23      3
# 156     3
# 200     3
# 123     3
# 72      3
# 25      3
# 70      3
# 14      3
# 174     3
# 30      3
# 84      3
# 29      3
# Name: Client ID, Length: 66, dtype: int64

# %% [markdown]
# Since there are 66 of 200 patients who have gone more than 3 times we can conclude that the majority of patients only seek services between 0-2 times. This is further supported by the section below that indicates the mean value of services is 2.57. A little bit over a 3rd of the patients seek services 3 or more times, I would be curious to observe how many of these individuals are homeless versus are not, as well as which hospitals these patients belong to. This could help identify groups that need more help, or hospitals that may require additional funding due to additional workload.

# %% [markdown]
# # Question 2 answer

# %%
S.mean() #identifying the mean value count or average number of times a patient used services
# Out:
# 2.57

# %%
S.median() #median can be a better identifyier because it isn't as susceptible to outliers such as Client 104 who went 15 times.
# Out:
# 2.0

# %% [markdown]
# This information would indicate that on average patients used services between 2 and 2.57 times. This could be an important observation because it indicates how frequently we can expect patients to seek out services.

# %% [markdown]
# ## Preparing to address instruction 3 for creating a chart that reflects the unique amount of clients who had jail services in FY 2016-2017 by jail facility

# %% [markdown]
#  Make a list of Subunit ID's and filter by the list

# %%
subid_list = ['1141', '1511', '1512', '1521', '1522', '1531', '1541'] #create a sublist based on the jail facility codes in subunit


client['SubUnit ID'].isin(subid_list)
#extract this by unique Client Id
new = client['SubUnit ID'].isin(subid_list) #create a new variable, True if present in those jail facilities, False if not present

# %%
new
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8       True
# 9       True
# 10      True
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18      True
# 19     False
# 20      True
# 21      True
# 22      True
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 484     True
# 485    False
# 486    False
# 487     True
# 488     True
# 489     True
# 490     True
# 491    False
# 492    False
# 493    False
# 494    False
# 495     True
# 496    False
# 497     True
# 498     True
# 499     True
# 500    False
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# 506     True
# 507    False
# 508    False
# 509     True
# 510     True
# 511     True
# 512     True
# 513     True
# Name: SubUnit ID, Length: 514, dtype: bool

# %%
newframe=client[new] #Clients who had jail services
newframe
# Out:
#     Client ID  SubUnit ID Service Date  Unnamed: 3  Unnamed: 4
# 2          91        1141   2016-07-01         NaN         NaN
# 5         115        1522   2016-07-02         NaN         NaN
# 8         199        1531   2016-07-04         NaN         NaN
# 9         178        1522   2016-07-05         NaN         NaN
# 10        144        1541   2016-07-05         NaN         NaN
# 13        172        1511   2016-07-06         NaN         NaN
# 16         26        1141   2016-07-07         NaN         NaN
# 17         46        1522   2016-07-07         NaN         NaN
# 18        135        1541   2016-07-07         NaN         NaN
# 20        193        1511   2016-07-08         NaN         NaN
# 21         34        1511   2016-07-08         NaN         NaN
# 22         47        1522   2016-07-08         NaN         NaN
# 35         34        1512   2016-07-16         NaN         NaN
# 37         23        1511   2016-07-19         NaN         NaN
# 43        160        1522   2016-07-20         NaN         NaN
# 44         23        1512   2016-07-21         NaN         NaN
# 45        176        1541   2016-07-21         NaN         NaN
# 47        143        1541   2016-07-22         NaN         NaN
# 48         68        1522   2016-07-23         NaN         NaN
# 52        122        1522   2016-07-25         NaN         NaN
# 56        178        1541   2016-07-26         NaN         NaN
# 58         72        1541   2016-07-27         NaN         NaN
# 65        128        1141   2016-07-29         NaN         NaN
# 69         91        1141   2016-08-01         NaN         NaN
# 70         23        1512   2016-08-01         NaN         NaN
# 71        186        1522   2016-08-02         NaN         NaN
# 72         72        1541   2016-08-02         NaN         NaN
# 76        199        1522   2016-08-05         NaN         NaN
# 77        129        1522   2016-08-05         NaN         NaN
# 82        130        1511   2016-08-09         NaN         NaN
# ..        ...         ...          ...         ...         ...
# 457       183        1541   2017-05-19         NaN         NaN
# 458       134        1541   2017-05-19         NaN         NaN
# 463        12        1522   2017-05-22         NaN         NaN
# 464       101        1541   2017-05-22         NaN         NaN
# 468        77        1141   2017-05-25         NaN         NaN
# 469        58        1541   2017-05-25         NaN         NaN
# 472       172        1511   2017-05-27         NaN         NaN
# 473        25        1541   2017-05-28         NaN         NaN
# 474       125        1511   2017-05-30         NaN         NaN
# 475        41        1511   2017-05-31         NaN         NaN
# 478       151        1522   2017-06-01         NaN         NaN
# 479       200        1521   2017-06-02         NaN         NaN
# 480       184        1522   2017-06-02         NaN         NaN
# 482       131        1511   2017-06-03         NaN         NaN
# 483       104        1522   2017-06-04         NaN         NaN
# 484       101        1541   2017-06-05         NaN         NaN
# 487       108        1511   2017-06-08         NaN         NaN
# 488       154        1511   2017-06-08         NaN         NaN
# 489        82        1541   2017-06-08         NaN         NaN
# 490       199        1541   2017-06-08         NaN         NaN
# 495       110        1511   2017-06-11         NaN         NaN
# 497       117        1511   2017-06-12         NaN         NaN
# 498       199        1141   2017-06-13         NaN         NaN
# 499        82        1141   2017-06-13         NaN         NaN
# 506       121        1541   2017-06-24         NaN         NaN
# 509       114        1522   2017-06-27         NaN         NaN
# 510       102        1522   2017-06-27         NaN         NaN
# 511        87        1541   2017-06-27         NaN         NaN
# 512       117        1511   2017-06-29         NaN         NaN
# 513        46        1541   2017-06-29         NaN         NaN
#
# [228 rows x 5 columns]

# %%
newframe['SubUnit ID'].astype(str) #change this data type to an object/string
# Out:
# 2      1141
# 5      1522
# 8      1531
# 9      1522
# 10     1541
# 13     1511
# 16     1141
# 17     1522
# 18     1541
# 20     1511
# 21     1511
# 22     1522
# 35     1512
# 37     1511
# 43     1522
# 44     1512
# 45     1541
# 47     1541
# 48     1522
# 52     1522
# 56     1541
# 58     1541
# 65     1141
# 69     1141
# 70     1512
# 71     1522
# 72     1541
# 76     1522
# 77     1522
# 82     1511
#        ...
# 457    1541
# 458    1541
# 463    1522
# 464    1541
# 468    1141
# 469    1541
# 472    1511
# 473    1541
# 474    1511
# 475    1511
# 478    1522
# 479    1521
# 480    1522
# 482    1511
# 483    1522
# 484    1541
# 487    1511
# 488    1511
# 489    1541
# 490    1541
# 495    1511
# 497    1511
# 498    1141
# 499    1141
# 506    1541
# 509    1522
# 510    1522
# 511    1541
# 512    1511
# 513    1541
# Name: SubUnit ID, Length: 228, dtype: object

# %%
client[new].groupby('Client ID')
client[new]
# Out:
#     Client ID  SubUnit ID Service Date  Unnamed: 3  Unnamed: 4
# 2          91        1141   2016-07-01         NaN         NaN
# 5         115        1522   2016-07-02         NaN         NaN
# 8         199        1531   2016-07-04         NaN         NaN
# 9         178        1522   2016-07-05         NaN         NaN
# 10        144        1541   2016-07-05         NaN         NaN
# 13        172        1511   2016-07-06         NaN         NaN
# 16         26        1141   2016-07-07         NaN         NaN
# 17         46        1522   2016-07-07         NaN         NaN
# 18        135        1541   2016-07-07         NaN         NaN
# 20        193        1511   2016-07-08         NaN         NaN
# 21         34        1511   2016-07-08         NaN         NaN
# 22         47        1522   2016-07-08         NaN         NaN
# 35         34        1512   2016-07-16         NaN         NaN
# 37         23        1511   2016-07-19         NaN         NaN
# 43        160        1522   2016-07-20         NaN         NaN
# 44         23        1512   2016-07-21         NaN         NaN
# 45        176        1541   2016-07-21         NaN         NaN
# 47        143        1541   2016-07-22         NaN         NaN
# 48         68        1522   2016-07-23         NaN         NaN
# 52        122        1522   2016-07-25         NaN         NaN
# 56        178        1541   2016-07-26         NaN         NaN
# 58         72        1541   2016-07-27         NaN         NaN
# 65        128        1141   2016-07-29         NaN         NaN
# 69         91        1141   2016-08-01         NaN         NaN
# 70         23        1512   2016-08-01         NaN         NaN
# 71        186        1522   2016-08-02         NaN         NaN
# 72         72        1541   2016-08-02         NaN         NaN
# 76        199        1522   2016-08-05         NaN         NaN
# 77        129        1522   2016-08-05         NaN         NaN
# 82        130        1511   2016-08-09         NaN         NaN
# ..        ...         ...          ...         ...         ...
# 457       183        1541   2017-05-19         NaN         NaN
# 458       134        1541   2017-05-19         NaN         NaN
# 463        12        1522   2017-05-22         NaN         NaN
# 464       101        1541   2017-05-22         NaN         NaN
# 468        77        1141   2017-05-25         NaN         NaN
# 469        58        1541   2017-05-25         NaN         NaN
# 472       172        1511   2017-05-27         NaN         NaN
# 473        25        1541   2017-05-28         NaN         NaN
# 474       125        1511   2017-05-30         NaN         NaN
# 475        41        1511   2017-05-31         NaN         NaN
# 478       151        1522   2017-06-01         NaN         NaN
# 479       200        1521   2017-06-02         NaN         NaN
# 480       184        1522   2017-06-02         NaN         NaN
# 482       131        1511   2017-06-03         NaN         NaN
# 483       104        1522   2017-06-04         NaN         NaN
# 484       101        1541   2017-06-05         NaN         NaN
# 487       108        1511   2017-06-08         NaN         NaN
# 488       154        1511   2017-06-08         NaN         NaN
# 489        82        1541   2017-06-08         NaN         NaN
# 490       199        1541   2017-06-08         NaN         NaN
# 495       110        1511   2017-06-11         NaN         NaN
# 497       117        1511   2017-06-12         NaN         NaN
# 498       199        1141   2017-06-13         NaN         NaN
# 499        82        1141   2017-06-13         NaN         NaN
# 506       121        1541   2017-06-24         NaN         NaN
# 509       114        1522   2017-06-27         NaN         NaN
# 510       102        1522   2017-06-27         NaN         NaN
# 511        87        1541   2017-06-27         NaN         NaN
# 512       117        1511   2017-06-29         NaN         NaN
# 513        46        1541   2017-06-29         NaN         NaN
#
# [228 rows x 5 columns]

# %%
newframe['SubUnit ID'].dtype
# Out:
# dtype('int64')

# %%
newframe['counts']= newframe.groupby(['SubUnit ID'])['Client ID'].transform('count') #create a column that couts the unique clients per facility
# Out:
# C:\Users\isaia\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
newframe
# Out:
#     Client ID  SubUnit ID Service Date  Unnamed: 3  Unnamed: 4  counts
# 2          91        1141   2016-07-01         NaN         NaN      24
# 5         115        1522   2016-07-02         NaN         NaN      83
# 8         199        1531   2016-07-04         NaN         NaN      10
# 9         178        1522   2016-07-05         NaN         NaN      83
# 10        144        1541   2016-07-05         NaN         NaN      57
# 13        172        1511   2016-07-06         NaN         NaN      37
# 16         26        1141   2016-07-07         NaN         NaN      24
# 17         46        1522   2016-07-07         NaN         NaN      83
# 18        135        1541   2016-07-07         NaN         NaN      57
# 20        193        1511   2016-07-08         NaN         NaN      37
# 21         34        1511   2016-07-08         NaN         NaN      37
# 22         47        1522   2016-07-08         NaN         NaN      83
# 35         34        1512   2016-07-16         NaN         NaN      11
# 37         23        1511   2016-07-19         NaN         NaN      37
# 43        160        1522   2016-07-20         NaN         NaN      83
# 44         23        1512   2016-07-21         NaN         NaN      11
# 45        176        1541   2016-07-21         NaN         NaN      57
# 47        143        1541   2016-07-22         NaN         NaN      57
# 48         68        1522   2016-07-23         NaN         NaN      83
# 52        122        1522   2016-07-25         NaN         NaN      83
# 56        178        1541   2016-07-26         NaN         NaN      57
# 58         72        1541   2016-07-27         NaN         NaN      57
# 65        128        1141   2016-07-29         NaN         NaN      24
# 69         91        1141   2016-08-01         NaN         NaN      24
# 70         23        1512   2016-08-01         NaN         NaN      11
# 71        186        1522   2016-08-02         NaN         NaN      83
# 72         72        1541   2016-08-02         NaN         NaN      57
# 76        199        1522   2016-08-05         NaN         NaN      83
# 77        129        1522   2016-08-05         NaN         NaN      83
# 82        130        1511   2016-08-09         NaN         NaN      37
# ..        ...         ...          ...         ...         ...     ...
# 457       183        1541   2017-05-19         NaN         NaN      57
# 458       134        1541   2017-05-19         NaN         NaN      57
# 463        12        1522   2017-05-22         NaN         NaN      83
# 464       101        1541   2017-05-22         NaN         NaN      57
# 468        77        1141   2017-05-25         NaN         NaN      24
# 469        58        1541   2017-05-25         NaN         NaN      57
# 472       172        1511   2017-05-27         NaN         NaN      37
# 473        25        1541   2017-05-28         NaN         NaN      57
# 474       125        1511   2017-05-30         NaN         NaN      37
# 475        41        1511   2017-05-31         NaN         NaN      37
# 478       151        1522   2017-06-01         NaN         NaN      83
# 479       200        1521   2017-06-02         NaN         NaN       6
# 480       184        1522   2017-06-02         NaN         NaN      83
# 482       131        1511   2017-06-03         NaN         NaN      37
# 483       104        1522   2017-06-04         NaN         NaN      83
# 484       101        1541   2017-06-05         NaN         NaN      57
# 487       108        1511   2017-06-08         NaN         NaN      37
# 488       154        1511   2017-06-08         NaN         NaN      37
# 489        82        1541   2017-06-08         NaN         NaN      57
# 490       199        1541   2017-06-08         NaN         NaN      57
# 495       110        1511   2017-06-11         NaN         NaN      37
# 497       117        1511   2017-06-12         NaN         NaN      37
# 498       199        1141   2017-06-13         NaN         NaN      24
# 499        82        1141   2017-06-13         NaN         NaN      24
# 506       121        1541   2017-06-24         NaN         NaN      57
# 509       114        1522   2017-06-27         NaN         NaN      83
# 510       102        1522   2017-06-27         NaN         NaN      83
# 511        87        1541   2017-06-27         NaN         NaN      57
# 512       117        1511   2017-06-29         NaN         NaN      37
# 513        46        1541   2017-06-29         NaN         NaN      57
#
# [228 rows x 6 columns]

# %%
counts2=client[new]['Client ID'].value_counts() #number of services used by client ID for each client
counts2
# Out:
# 143    9
# 41     8
# 199    7
# 34     7
# 82     6
# 46     5
# 130    5
# 186    5
# 162    5
# 85     4
# 151    4
# 122    4
# 47     4
# 1      4
# 178    4
# 68     4
# 25     3
# 197    3
# 91     3
# 101    3
# 87     3
# 72     3
# 70     3
# 129    3
# 144    3
# 174    3
# 183    3
# 23     3
# 30     3
# 118    3
#       ..
# 19     1
# 160    1
# 12     1
# 103    1
# 22     1
# 102    1
# 191    1
# 200    1
# 26     1
# 92     1
# 57     1
# 5      1
# 60     1
# 7      1
# 105    1
# 193    1
# 195    1
# 158    1
# 108    1
# 61     1
# 10     1
# 65     1
# 194    1
# 154    1
# 169    1
# 115    1
# 185    1
# 167    1
# 184    1
# 114    1
# Name: Client ID, Length: 108, dtype: int64

# %% [markdown]
# # Creating a visual to show subunit ID as X, and number of occurences for each SubUnit as Y in order to show unique number of clients

# %%
ax = newframe['SubUnit ID'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number of unique amount of clients who had jail services in 16/17 by jail facility")
ax.set_xlabel("SubUnit for prisons")
ax.set_ylabel("Unique Number of Clients")
# Out:
# Text(0, 0.5, 'Unique Number of Clients')

# %% [markdown]
# Important to note that 1522 or Central Jail had the most unique amount of clients who had services at 83, while 1521 had the least with 6. Central jails are 1522, 1541, 1521, and 1141 while Eastern are 1511, and 1512. The Vista facility is 1531 located in the North coastal area. It would appear that the majority of clients are from the Central jails, perhaps indicating need for further study practices implemented by these jails.

# %% [markdown]
# ## Preparing to address Question 4. Create a table that reflects the number of IP Hospital services in FY 2016-17 broken down by month and hospital name. Note any findings.

# %%
df_dict['Instructions']
# Out:
# Empty DataFrame
# Columns: []
# Index: [Answer as many of the below Report Questions in the "Report" tab that you can., Please show your work (formulas, pivot tables, etc.) and don’t be afraid to be creative with charts and graphs!, Create a dashboard using the program of your choice (Excel/PowerBi/Python/Etc..) to visually display your data., Compose a short narrative to explain your findings., Report Questions, • How many clients had 3 or more services in FY 2016-17?, • What was the average amount of services per client in FY 2016-17?, • Create a chart that reflects the unique amount of clients who had jail services in FY 2016-17 broken down by Jail facility.  Note any findings., • Create a table that reflects the number of IP Hospital services in FY 2016-17 broken down by month and hospital name.  Note any findings., • What percentage of unique clients that received IP Hospital services in FY 2016-17 were homeless?, • Note any other interesting findings from the data., Term Definitions, IP Hospital - Psychiatric Inpatient Hospital, PERT - Psychiatric Emergency Response Team, Jail - Mental Health Services Received in a Jail Facility]

# %%
SD=df_dict['Service Descriptions']

# %%
C=df_dict['Client Services in FY 2016-17']

# %% [markdown]
# # This time I am going to need a dataframe that has not only the information from the Client services sheet, but also add both facility name and service category, this can likely be accomplished through a merge and creating on a new dataframe

# %%
S.update(C)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-9fe8c32f0173> in <module>
# ----> 1 S.update(C)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in update(self, other)
#    2328
#    2329         """
# -> 2330         other = other.reindex_like(self)
#    2331         mask = notna(other)
#    2332
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex_like(self, other, method, copy, limit, tolerance)
#    3084         d = other._construct_axes_dict(axes=self._AXIS_ORDERS, method=method,
#    3085                                        copy=copy, limit=limit,
# -> 3086                                        tolerance=tolerance)
#    3087
#    3088         return self.reindex(**d)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _construct_axes_dict(self, axes, **kwargs)
#     297     def _construct_axes_dict(self, axes=None, **kwargs):
#     298         """Return an axes dictionary for myself."""
# --> 299         d = {a: self._get_axis(a) for a in (axes or self._AXIS_ORDERS)}
#     300         d.update(kwargs)
#     301         return d
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in <dictcomp>(.0)
#     297     def _construct_axes_dict(self, axes=None, **kwargs):
#     298         """Return an axes dictionary for myself."""
# --> 299         d = {a: self._get_axis(a) for a in (axes or self._AXIS_ORDERS)}
#     300         d.update(kwargs)
#     301         return d
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis(self, axis)
#     389
#     390     def _get_axis(self, axis):
# --> 391         name = self._get_axis_name(axis)
#     392         return getattr(self, name)
#     393
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_name(self, axis)
#     386                 pass
#     387         raise ValueError('No axis named {0} for object type {1}'
# --> 388                          .format(axis, type(self)))
#     389
#     390     def _get_axis(self, axis):
#
# ValueError: No axis named columns for object type <class 'pandas.core.series.Series'>

# %%
dict3

# %%
 # Code used to created a new merged dataset since dictionaries aren't working for now

import pandas as pd

path= (r'C:\Users\isaia\Downloads\Skills Assessment December 2020.xlsx')

client_services = pd.read_excel(path, sheet_name='Client Services in FY 2016-17')

client_services


descriptions = pd.read_excel(path, sheet_name='Service Descriptions')

descriptions

clients_sheet= pd.read_excel(path, sheet_name= ('Clients'))
clients_sheet


client_services = client_services.merge(descriptions, on='SubUnit ID', how='left')
client_services= client_services.merge(clients_sheet, on='Client ID', how='left')

client_services.to_csv('C:\Users\isaia\Downloads\combined_services.csv')
# Out:
#   File "<ipython-input-73-3555daf77099>", line 23
#     client_services.to_csv('C:\Users\isaia\Downloads\combined_services.csv')
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
path= (r'C:\Users\isaia\Downloads\Skills Assessment December 2020.xlsx')

# %%
client_services = pd.read_excel(path, sheet_name='Client Services in FY 2016-17')
client_services
# Out:
#      Client ID  SubUnit ID Service Date  Unnamed: 3  Unnamed: 4
# 0           19        9502   2016-07-01         NaN         NaN
# 1          158        9503   2016-07-01         NaN         NaN
# 2           91        1141   2016-07-01         NaN         NaN
# 3           11        9507   2016-07-02         NaN         NaN
# 4          137        4131   2016-07-02         NaN         NaN
# 5          115        1522   2016-07-02         NaN         NaN
# 6            4        1211   2016-07-03         NaN         NaN
# 7          186        1211   2016-07-04         NaN         NaN
# 8          199        1531   2016-07-04         NaN         NaN
# 9          178        1522   2016-07-05         NaN         NaN
# 10         144        1541   2016-07-05         NaN         NaN
# 11          59        9501   2016-07-06         NaN        83.0
# 12          76        9503   2016-07-06         NaN         NaN
# 13         172        1511   2016-07-06         NaN         NaN
# 14         148        1211   2016-07-07         NaN         NaN
# 15         104        9502   2016-07-07         NaN         NaN
# 16          26        1141   2016-07-07         NaN         NaN
# 17          46        1522   2016-07-07         NaN         NaN
# 18         135        1541   2016-07-07         NaN         NaN
# 19          97        9505   2016-07-08         NaN         NaN
# 20         193        1511   2016-07-08         NaN         NaN
# 21          34        1511   2016-07-08         NaN         NaN
# 22          47        1522   2016-07-08         NaN         NaN
# 23         155        4131   2016-07-11         NaN         NaN
# 24         109        1211   2016-07-12         NaN         NaN
# 25          10        9502   2016-07-12         NaN         NaN
# 26         152        9503   2016-07-12         NaN         NaN
# 27          68        4131   2016-07-12         NaN         NaN
# 28          68        4132   2016-07-12         NaN         NaN
# 29         182        1211   2016-07-13         NaN         NaN
# ..         ...         ...          ...         ...         ...
# 484        101        1541   2017-06-05         NaN         NaN
# 485        100        1211   2017-06-06         NaN         NaN
# 486        198        9504   2017-06-07         NaN         NaN
# 487        108        1511   2017-06-08         NaN         NaN
# 488        154        1511   2017-06-08         NaN         NaN
# 489         82        1541   2017-06-08         NaN         NaN
# 490        199        1541   2017-06-08         NaN         NaN
# 491         35        4131   2017-06-09         NaN         NaN
# 492        132        1211   2017-06-11         NaN         NaN
# 493        187        9503   2017-06-11         NaN         NaN
# 494         35        9505   2017-06-11         NaN         NaN
# 495        110        1511   2017-06-11         NaN         NaN
# 496        111        9502   2017-06-12         NaN         NaN
# 497        117        1511   2017-06-12         NaN         NaN
# 498        199        1141   2017-06-13         NaN         NaN
# 499         82        1141   2017-06-13         NaN         NaN
# 500        193        4132   2017-06-15         NaN         NaN
# 501        172        9502   2017-06-16         NaN         NaN
# 502        200        4131   2017-06-16         NaN         NaN
# 503        163        4131   2017-06-16         NaN         NaN
# 504        104        9503   2017-06-21         NaN         NaN
# 505        120        9503   2017-06-22         NaN         NaN
# 506        121        1541   2017-06-24         NaN         NaN
# 507         79        4131   2017-06-25         NaN         NaN
# 508         11        9508   2017-06-27         NaN         NaN
# 509        114        1522   2017-06-27         NaN         NaN
# 510        102        1522   2017-06-27         NaN         NaN
# 511         87        1541   2017-06-27         NaN         NaN
# 512        117        1511   2017-06-29         NaN         NaN
# 513         46        1541   2017-06-29         NaN         NaN
#
# [514 rows x 5 columns]

# %%
descriptions = pd.read_excel(path, sheet_name='Service Descriptions')

descriptions
# Out:
#     SubUnit ID           Service Facility Name Service Category         Region
# 0         1211       CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central
# 1         9501             ALVARADO PKWY INST       IP Hospital           East
# 2         9502             PH BAYVIEW HOSPITAL      IP Hospital          South
# 3         9503         PH PARADISE VALLEY HOSP      IP Hospital          South
# 4         9504             UCSD MEDICAL CENTER      IP Hospital        Central
# 5         9505            SHARP GROSSMONT HOSP      IP Hospital           East
# 6         9506        SCRIPPS MERCY HEALTHCARE      IP Hospital        Central
# 7         9507          PALOMAR MEDICAL CENTER      IP Hospital   North Inland
# 8         9508               TRI-CITY HOSPITAL      IP Hospital  North Coastal
# 9         9511       SHARP MESA VISTA HOSP (A)      IP Hospital  North Central
# 10        9515        OUT OF COUNTY HOSP ADULT      IP Hospital     No Address
# 11        4131                   CRF PERT MHSA             PERT  North Central
# 12        4132                  CRF PERT STAFF             PERT  North Central
# 13        1141         CO Adult Forensics Eval             Jail        Central
# 14        1511               CO Las Colinas OP             Jail           East
# 15        1512         CO Las Colinas IP (PSU)             Jail           East
# 16        1521        CO Central Jail IP (PSU)             Jail        Central
# 17        1522              CO Central Jail OP             Jail        Central
# 18        1531  CO Vista Detention Facility OP             Jail  North Coastal
# 19        1541   CO George Bailey Detention OP             Jail        Central

# %%
clients_sheet = pd.read_excel(path, sheet_name= ('Clients'))
clients_sheet
# Out:
#      Client ID  Gender Homeless Status
# 0            1    Male        Homeless
# 1            2    Male    Not Homeless
# 2            3  Female    Not Homeless
# 3            4  Female    Not Homeless
# 4            5    Male    Not Homeless
# 5            6    Male        Homeless
# 6            7    Male    Not Homeless
# 7            8    Male    Not Homeless
# 8            9  Female    Not Homeless
# 9           10    Male    Not Homeless
# 10          11    Male    Not Homeless
# 11          12    Male    Not Homeless
# 12          13  Female        Homeless
# 13          14    Male    Not Homeless
# 14          15    Male    Not Homeless
# 15          16    Male    Not Homeless
# 16          17  Female        Homeless
# 17          18    Male    Not Homeless
# 18          19    Male        Homeless
# 19          20  Female    Not Homeless
# 20          21    Male    Not Homeless
# 21          22    Male    Not Homeless
# 22          23  Female    Not Homeless
# 23          24  Female    Not Homeless
# 24          25    Male    Not Homeless
# 25          26  Female    Not Homeless
# 26          27    Male    Not Homeless
# 27          28  Female    Not Homeless
# 28          29    Male    Not Homeless
# 29          30    Male    Not Homeless
# ..         ...     ...             ...
# 170        171    Male    Not Homeless
# 171        172  Female        Homeless
# 172        173  Female    Not Homeless
# 173        174    Male        Homeless
# 174        175  Female    Not Homeless
# 175        176    Male    Not Homeless
# 176        177    Male    Not Homeless
# 177        178    Male        Homeless
# 178        179  Female    Not Homeless
# 179        180    Male    Not Homeless
# 180        181    Male    Not Homeless
# 181        182  Female        Homeless
# 182        183    Male        Homeless
# 183        184    Male        Homeless
# 184        185    Male    Not Homeless
# 185        186    Male        Homeless
# 186        187    Male    Not Homeless
# 187        188  Female        Homeless
# 188        189    Male    Not Homeless
# 189        190  Female    Not Homeless
# 190        191    Male    Not Homeless
# 191        192  Female    Not Homeless
# 192        193  Female    Not Homeless
# 193        194    Male        Homeless
# 194        195    Male    Not Homeless
# 195        196    Male        Homeless
# 196        197    Male    Not Homeless
# 197        198  Female    Not Homeless
# 198        199    Male        Homeless
# 199        200    Male        Homeless
#
# [200 rows x 3 columns]

# %%
client_services = client_services.merge(descriptions, on='SubUnit ID', how='left')

# %%
client_services= client_services.merge(clients_sheet, on='Client ID', how='left')

# %%
client_services.to_csv(r'C:\Users\isaia\Downloads\combined_services.csv')

# %%
df_merged = pd.read_csv (r'C:\Users\isaia\Downloads\combined_services.csv', index_col=0)
print (df_merged)
# Out:
#      Client ID  SubUnit ID Service Date  Unnamed: 3  Unnamed: 4  \
# 0           19        9502   2016-07-01         NaN         NaN
# 1          158        9503   2016-07-01         NaN         NaN
# 2           91        1141   2016-07-01         NaN         NaN
# 3           11        9507   2016-07-02         NaN         NaN
# 4          137        4131   2016-07-02         NaN         NaN
# 5          115        1522   2016-07-02         NaN         NaN
# 6            4        1211   2016-07-03         NaN         NaN
# 7          186        1211   2016-07-04         NaN         NaN
# 8          199        1531   2016-07-04         NaN         NaN
# 9          178        1522   2016-07-05         NaN         NaN
# 10         144        1541   2016-07-05         NaN         NaN
# 11          59        9501   2016-07-06         NaN        83.0
# 12          76        9503   2016-07-06         NaN         NaN
# 13         172        1511   2016-07-06         NaN         NaN
# 14         148        1211   2016-07-07         NaN         NaN
# 15         104        9502   2016-07-07         NaN         NaN
# 16          26        1141   2016-07-07         NaN         NaN
# 17          46        1522   2016-07-07         NaN         NaN
# 18         135        1541   2016-07-07         NaN         NaN
# 19          97        9505   2016-07-08         NaN         NaN
# 20         193        1511   2016-07-08         NaN         NaN
# 21          34        1511   2016-07-08         NaN         NaN
# 22          47        1522   2016-07-08         NaN         NaN
# 23         155        4131   2016-07-11         NaN         NaN
# 24         109        1211   2016-07-12         NaN         NaN
# 25          10        9502   2016-07-12         NaN         NaN
# 26         152        9503   2016-07-12         NaN         NaN
# 27          68        4131   2016-07-12         NaN         NaN
# 28          68        4132   2016-07-12         NaN         NaN
# 29         182        1211   2016-07-13         NaN         NaN
# ..         ...         ...          ...         ...         ...
# 484        101        1541   2017-06-05         NaN         NaN
# 485        100        1211   2017-06-06         NaN         NaN
# 486        198        9504   2017-06-07         NaN         NaN
# 487        108        1511   2017-06-08         NaN         NaN
# 488        154        1511   2017-06-08         NaN         NaN
# 489         82        1541   2017-06-08         NaN         NaN
# 490        199        1541   2017-06-08         NaN         NaN
# 491         35        4131   2017-06-09         NaN         NaN
# 492        132        1211   2017-06-11         NaN         NaN
# 493        187        9503   2017-06-11         NaN         NaN
# 494         35        9505   2017-06-11         NaN         NaN
# 495        110        1511   2017-06-11         NaN         NaN
# 496        111        9502   2017-06-12         NaN         NaN
# 497        117        1511   2017-06-12         NaN         NaN
# 498        199        1141   2017-06-13         NaN         NaN
# 499         82        1141   2017-06-13         NaN         NaN
# 500        193        4132   2017-06-15         NaN         NaN
# 501        172        9502   2017-06-16         NaN         NaN
# 502        200        4131   2017-06-16         NaN         NaN
# 503        163        4131   2017-06-16         NaN         NaN
# 504        104        9503   2017-06-21         NaN         NaN
# 505        120        9503   2017-06-22         NaN         NaN
# 506        121        1541   2017-06-24         NaN         NaN
# 507         79        4131   2017-06-25         NaN         NaN
# 508         11        9508   2017-06-27         NaN         NaN
# 509        114        1522   2017-06-27         NaN         NaN
# 510        102        1522   2017-06-27         NaN         NaN
# 511         87        1541   2017-06-27         NaN         NaN
# 512        117        1511   2017-06-29         NaN         NaN
# 513         46        1541   2017-06-29         NaN         NaN
#
#               Service Facility Name Service Category         Region  Gender  \
# 0               PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 1           PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 2           CO Adult Forensics Eval             Jail        Central    Male
# 3            PALOMAR MEDICAL CENTER      IP Hospital   North Inland    Male
# 4                     CRF PERT MHSA             PERT  North Central    Male
# 5                CO Central Jail OP             Jail        Central    Male
# 6         CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 7         CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 8    CO Vista Detention Facility OP             Jail  North Coastal    Male
# 9                CO Central Jail OP             Jail        Central    Male
# 10    CO George Bailey Detention OP             Jail        Central    Male
# 11              ALVARADO PKWY INST       IP Hospital           East  Female
# 12          PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 13                CO Las Colinas OP             Jail           East  Female
# 14        CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 15              PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 16          CO Adult Forensics Eval             Jail        Central  Female
# 17               CO Central Jail OP             Jail        Central    Male
# 18    CO George Bailey Detention OP             Jail        Central    Male
# 19             SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 20                CO Las Colinas OP             Jail           East  Female
# 21                CO Las Colinas OP             Jail           East  Female
# 22               CO Central Jail OP             Jail        Central    Male
# 23                    CRF PERT MHSA             PERT  North Central    Male
# 24        CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 25              PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 26          PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 27                    CRF PERT MHSA             PERT  North Central    Male
# 28                   CRF PERT STAFF             PERT  North Central    Male
# 29        CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# ..                              ...              ...            ...     ...
# 484   CO George Bailey Detention OP             Jail        Central    Male
# 485       CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 486             UCSD MEDICAL CENTER      IP Hospital        Central  Female
# 487               CO Las Colinas OP             Jail           East  Female
# 488               CO Las Colinas OP             Jail           East  Female
# 489   CO George Bailey Detention OP             Jail        Central    Male
# 490   CO George Bailey Detention OP             Jail        Central    Male
# 491                   CRF PERT MHSA             PERT  North Central  Female
# 492       CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 493         PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 494            SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 495               CO Las Colinas OP             Jail           East  Female
# 496             PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 497               CO Las Colinas OP             Jail           East  Female
# 498         CO Adult Forensics Eval             Jail        Central    Male
# 499         CO Adult Forensics Eval             Jail        Central    Male
# 500                  CRF PERT STAFF             PERT  North Central  Female
# 501             PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 502                   CRF PERT MHSA             PERT  North Central    Male
# 503                   CRF PERT MHSA             PERT  North Central    Male
# 504         PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 505         PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 506   CO George Bailey Detention OP             Jail        Central    Male
# 507                   CRF PERT MHSA             PERT  North Central  Female
# 508               TRI-CITY HOSPITAL      IP Hospital  North Coastal    Male
# 509              CO Central Jail OP             Jail        Central    Male
# 510              CO Central Jail OP             Jail        Central    Male
# 511   CO George Bailey Detention OP             Jail        Central    Male
# 512               CO Las Colinas OP             Jail           East  Female
# 513   CO George Bailey Detention OP             Jail        Central    Male
#
#     Homeless Status
# 0          Homeless
# 1      Not Homeless
# 2      Not Homeless
# 3      Not Homeless
# 4      Not Homeless
# 5      Not Homeless
# 6      Not Homeless
# 7          Homeless
# 8          Homeless
# 9          Homeless
# 10     Not Homeless
# 11     Not Homeless
# 12     Not Homeless
# 13         Homeless
# 14     Not Homeless
# 15     Not Homeless
# 16     Not Homeless
# 17         Homeless
# 18         Homeless
# 19     Not Homeless
# 20     Not Homeless
# 21         Homeless
# 22     Not Homeless
# 23     Not Homeless
# 24     Not Homeless
# 25     Not Homeless
# 26     Not Homeless
# 27     Not Homeless
# 28     Not Homeless
# 29         Homeless
# ..              ...
# 484    Not Homeless
# 485    Not Homeless
# 486    Not Homeless
# 487    Not Homeless
# 488    Not Homeless
# 489        Homeless
# 490        Homeless
# 491        Homeless
# 492        Homeless
# 493    Not Homeless
# 494        Homeless
# 495    Not Homeless
# 496    Not Homeless
# 497    Not Homeless
# 498        Homeless
# 499        Homeless
# 500    Not Homeless
# 501        Homeless
# 502        Homeless
# 503    Not Homeless
# 504    Not Homeless
# 505    Not Homeless
# 506    Not Homeless
# 507    Not Homeless
# 508    Not Homeless
# 509        Homeless
# 510    Not Homeless
# 511        Homeless
# 512    Not Homeless
# 513        Homeless
#
# [514 rows x 10 columns]

# %%
df_merged
# Out:
#      Client ID  SubUnit ID Service Date  Unnamed: 3  Unnamed: 4  \
# 0           19        9502   2016-07-01         NaN         NaN
# 1          158        9503   2016-07-01         NaN         NaN
# 2           91        1141   2016-07-01         NaN         NaN
# 3           11        9507   2016-07-02         NaN         NaN
# 4          137        4131   2016-07-02         NaN         NaN
# 5          115        1522   2016-07-02         NaN         NaN
# 6            4        1211   2016-07-03         NaN         NaN
# 7          186        1211   2016-07-04         NaN         NaN
# 8          199        1531   2016-07-04         NaN         NaN
# 9          178        1522   2016-07-05         NaN         NaN
# 10         144        1541   2016-07-05         NaN         NaN
# 11          59        9501   2016-07-06         NaN        83.0
# 12          76        9503   2016-07-06         NaN         NaN
# 13         172        1511   2016-07-06         NaN         NaN
# 14         148        1211   2016-07-07         NaN         NaN
# 15         104        9502   2016-07-07         NaN         NaN
# 16          26        1141   2016-07-07         NaN         NaN
# 17          46        1522   2016-07-07         NaN         NaN
# 18         135        1541   2016-07-07         NaN         NaN
# 19          97        9505   2016-07-08         NaN         NaN
# 20         193        1511   2016-07-08         NaN         NaN
# 21          34        1511   2016-07-08         NaN         NaN
# 22          47        1522   2016-07-08         NaN         NaN
# 23         155        4131   2016-07-11         NaN         NaN
# 24         109        1211   2016-07-12         NaN         NaN
# 25          10        9502   2016-07-12         NaN         NaN
# 26         152        9503   2016-07-12         NaN         NaN
# 27          68        4131   2016-07-12         NaN         NaN
# 28          68        4132   2016-07-12         NaN         NaN
# 29         182        1211   2016-07-13         NaN         NaN
# ..         ...         ...          ...         ...         ...
# 484        101        1541   2017-06-05         NaN         NaN
# 485        100        1211   2017-06-06         NaN         NaN
# 486        198        9504   2017-06-07         NaN         NaN
# 487        108        1511   2017-06-08         NaN         NaN
# 488        154        1511   2017-06-08         NaN         NaN
# 489         82        1541   2017-06-08         NaN         NaN
# 490        199        1541   2017-06-08         NaN         NaN
# 491         35        4131   2017-06-09         NaN         NaN
# 492        132        1211   2017-06-11         NaN         NaN
# 493        187        9503   2017-06-11         NaN         NaN
# 494         35        9505   2017-06-11         NaN         NaN
# 495        110        1511   2017-06-11         NaN         NaN
# 496        111        9502   2017-06-12         NaN         NaN
# 497        117        1511   2017-06-12         NaN         NaN
# 498        199        1141   2017-06-13         NaN         NaN
# 499         82        1141   2017-06-13         NaN         NaN
# 500        193        4132   2017-06-15         NaN         NaN
# 501        172        9502   2017-06-16         NaN         NaN
# 502        200        4131   2017-06-16         NaN         NaN
# 503        163        4131   2017-06-16         NaN         NaN
# 504        104        9503   2017-06-21         NaN         NaN
# 505        120        9503   2017-06-22         NaN         NaN
# 506        121        1541   2017-06-24         NaN         NaN
# 507         79        4131   2017-06-25         NaN         NaN
# 508         11        9508   2017-06-27         NaN         NaN
# 509        114        1522   2017-06-27         NaN         NaN
# 510        102        1522   2017-06-27         NaN         NaN
# 511         87        1541   2017-06-27         NaN         NaN
# 512        117        1511   2017-06-29         NaN         NaN
# 513         46        1541   2017-06-29         NaN         NaN
#
#               Service Facility Name Service Category         Region  Gender  \
# 0               PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 1           PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 2           CO Adult Forensics Eval             Jail        Central    Male
# 3            PALOMAR MEDICAL CENTER      IP Hospital   North Inland    Male
# 4                     CRF PERT MHSA             PERT  North Central    Male
# 5                CO Central Jail OP             Jail        Central    Male
# 6         CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 7         CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 8    CO Vista Detention Facility OP             Jail  North Coastal    Male
# 9                CO Central Jail OP             Jail        Central    Male
# 10    CO George Bailey Detention OP             Jail        Central    Male
# 11              ALVARADO PKWY INST       IP Hospital           East  Female
# 12          PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 13                CO Las Colinas OP             Jail           East  Female
# 14        CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 15              PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 16          CO Adult Forensics Eval             Jail        Central  Female
# 17               CO Central Jail OP             Jail        Central    Male
# 18    CO George Bailey Detention OP             Jail        Central    Male
# 19             SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 20                CO Las Colinas OP             Jail           East  Female
# 21                CO Las Colinas OP             Jail           East  Female
# 22               CO Central Jail OP             Jail        Central    Male
# 23                    CRF PERT MHSA             PERT  North Central    Male
# 24        CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 25              PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 26          PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 27                    CRF PERT MHSA             PERT  North Central    Male
# 28                   CRF PERT STAFF             PERT  North Central    Male
# 29        CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# ..                              ...              ...            ...     ...
# 484   CO George Bailey Detention OP             Jail        Central    Male
# 485       CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 486             UCSD MEDICAL CENTER      IP Hospital        Central  Female
# 487               CO Las Colinas OP             Jail           East  Female
# 488               CO Las Colinas OP             Jail           East  Female
# 489   CO George Bailey Detention OP             Jail        Central    Male
# 490   CO George Bailey Detention OP             Jail        Central    Male
# 491                   CRF PERT MHSA             PERT  North Central  Female
# 492       CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 493         PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 494            SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 495               CO Las Colinas OP             Jail           East  Female
# 496             PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 497               CO Las Colinas OP             Jail           East  Female
# 498         CO Adult Forensics Eval             Jail        Central    Male
# 499         CO Adult Forensics Eval             Jail        Central    Male
# 500                  CRF PERT STAFF             PERT  North Central  Female
# 501             PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 502                   CRF PERT MHSA             PERT  North Central    Male
# 503                   CRF PERT MHSA             PERT  North Central    Male
# 504         PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 505         PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 506   CO George Bailey Detention OP             Jail        Central    Male
# 507                   CRF PERT MHSA             PERT  North Central  Female
# 508               TRI-CITY HOSPITAL      IP Hospital  North Coastal    Male
# 509              CO Central Jail OP             Jail        Central    Male
# 510              CO Central Jail OP             Jail        Central    Male
# 511   CO George Bailey Detention OP             Jail        Central    Male
# 512               CO Las Colinas OP             Jail           East  Female
# 513   CO George Bailey Detention OP             Jail        Central    Male
#
#     Homeless Status
# 0          Homeless
# 1      Not Homeless
# 2      Not Homeless
# 3      Not Homeless
# 4      Not Homeless
# 5      Not Homeless
# 6      Not Homeless
# 7          Homeless
# 8          Homeless
# 9          Homeless
# 10     Not Homeless
# 11     Not Homeless
# 12     Not Homeless
# 13         Homeless
# 14     Not Homeless
# 15     Not Homeless
# 16     Not Homeless
# 17         Homeless
# 18         Homeless
# 19     Not Homeless
# 20     Not Homeless
# 21         Homeless
# 22     Not Homeless
# 23     Not Homeless
# 24     Not Homeless
# 25     Not Homeless
# 26     Not Homeless
# 27     Not Homeless
# 28     Not Homeless
# 29         Homeless
# ..              ...
# 484    Not Homeless
# 485    Not Homeless
# 486    Not Homeless
# 487    Not Homeless
# 488    Not Homeless
# 489        Homeless
# 490        Homeless
# 491        Homeless
# 492        Homeless
# 493    Not Homeless
# 494        Homeless
# 495    Not Homeless
# 496    Not Homeless
# 497    Not Homeless
# 498        Homeless
# 499        Homeless
# 500    Not Homeless
# 501        Homeless
# 502        Homeless
# 503    Not Homeless
# 504    Not Homeless
# 505    Not Homeless
# 506    Not Homeless
# 507    Not Homeless
# 508    Not Homeless
# 509        Homeless
# 510    Not Homeless
# 511        Homeless
# 512    Not Homeless
# 513        Homeless
#
# [514 rows x 10 columns]

# %%
df_merged['SubUnit ID'].astype(str)
# Out:
# 0      9502
# 1      9503
# 2      1141
# 3      9507
# 4      4131
# 5      1522
# 6      1211
# 7      1211
# 8      1531
# 9      1522
# 10     1541
# 11     9501
# 12     9503
# 13     1511
# 14     1211
# 15     9502
# 16     1141
# 17     1522
# 18     1541
# 19     9505
# 20     1511
# 21     1511
# 22     1522
# 23     4131
# 24     1211
# 25     9502
# 26     9503
# 27     4131
# 28     4132
# 29     1211
#        ...
# 484    1541
# 485    1211
# 486    9504
# 487    1511
# 488    1511
# 489    1541
# 490    1541
# 491    4131
# 492    1211
# 493    9503
# 494    9505
# 495    1511
# 496    9502
# 497    1511
# 498    1141
# 499    1141
# 500    4132
# 501    9502
# 502    4131
# 503    4131
# 504    9503
# 505    9503
# 506    1541
# 507    4131
# 508    9508
# 509    1522
# 510    1522
# 511    1541
# 512    1511
# 513    1541
# Name: SubUnit ID, Length: 514, dtype: object

# %% [markdown]
# Create a table that reflects the number of IP Hospital services in FY 2016-17 broken down by month and hospital name. Note any findings.

# %%
subid_list_hosp = ['1211', '9501', '9502','9503','9504','9505','9506','9507','9508','9511','9515'] #create a sublist based on the IP hospital codes in subunit


df_merged['SubUnit ID'].isin(subid_list_hosp)
#extract this by unique Client Id
new_hosp = df_merged['SubUnit ID'].isin(subid_list_hosp) #create a new variable, True if present in those IP Hospital, False if not present

# %%
new_hosp
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
# 5      False
# 6       True
# 7       True
# 8      False
# 9      False
# 10     False
# 11      True
# 12      True
# 13     False
# 14      True
# 15      True
# 16     False
# 17     False
# 18     False
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25      True
# 26      True
# 27     False
# 28     False
# 29      True
#        ...
# 484    False
# 485     True
# 486     True
# 487    False
# 488    False
# 489    False
# 490    False
# 491    False
# 492     True
# 493     True
# 494     True
# 495    False
# 496     True
# 497    False
# 498    False
# 499    False
# 500    False
# 501     True
# 502    False
# 503    False
# 504     True
# 505     True
# 506    False
# 507    False
# 508     True
# 509    False
# 510    False
# 511    False
# 512    False
# 513    False
# Name: SubUnit ID, Length: 514, dtype: bool

# %%
hosp_frame=df_merged[new_hosp] #Clients who had hospital services
hosp_frame
# Out:
#      Client ID  SubUnit ID Service Date  Unnamed: 3  Unnamed: 4  \
# 0           19        9502   2016-07-01         NaN         NaN
# 1          158        9503   2016-07-01         NaN         NaN
# 3           11        9507   2016-07-02         NaN         NaN
# 6            4        1211   2016-07-03         NaN         NaN
# 7          186        1211   2016-07-04         NaN         NaN
# 11          59        9501   2016-07-06         NaN        83.0
# 12          76        9503   2016-07-06         NaN         NaN
# 14         148        1211   2016-07-07         NaN         NaN
# 15         104        9502   2016-07-07         NaN         NaN
# 19          97        9505   2016-07-08         NaN         NaN
# 24         109        1211   2016-07-12         NaN         NaN
# 25          10        9502   2016-07-12         NaN         NaN
# 26         152        9503   2016-07-12         NaN         NaN
# 29         182        1211   2016-07-13         NaN         NaN
# 30         104        9502   2016-07-13         NaN         NaN
# 31          74        9502   2016-07-14         NaN         NaN
# 32         157        9503   2016-07-14         NaN         NaN
# 38         137        9501   2016-07-20         NaN         NaN
# 39           9        9503   2016-07-20         NaN         NaN
# 40          57        9503   2016-07-20         NaN         NaN
# 50         130        9502   2016-07-25         NaN         NaN
# 53          64        9502   2016-07-26         NaN         NaN
# 59          11        9506   2016-07-28         NaN         NaN
# 61          10        9502   2016-07-29         NaN         NaN
# 62          68        9503   2016-07-29         NaN         NaN
# 66          48        1211   2016-07-31         NaN         NaN
# 67         172        9505   2016-07-31         NaN         NaN
# 73           4        9502   2016-08-04         NaN         NaN
# 74          87        9503   2016-08-04         NaN         NaN
# 75          38        9506   2016-08-04         NaN         NaN
# ..         ...         ...          ...         ...         ...
# 418        172        9511   2017-05-02         NaN         NaN
# 422        120        9503   2017-05-03         NaN         NaN
# 425         64        9502   2017-05-04         NaN         NaN
# 428        111        9502   2017-05-06         NaN         NaN
# 430         76        9506   2017-05-08         NaN         NaN
# 431        104        9502   2017-05-09         NaN         NaN
# 434        157        9503   2017-05-10         NaN         NaN
# 435         73        9511   2017-05-10         NaN         NaN
# 436          7        9503   2017-05-11         NaN         NaN
# 437        156        9507   2017-05-11         NaN         NaN
# 441        184        9515   2017-05-13         NaN         NaN
# 443        104        9502   2017-05-16         NaN         NaN
# 447         44        9502   2017-05-17         NaN         NaN
# 448         10        9503   2017-05-17         NaN         NaN
# 449         69        9505   2017-05-17         NaN         NaN
# 453        187        9503   2017-05-18         NaN         NaN
# 460        100        9504   2017-05-22         NaN         NaN
# 461        185        9511   2017-05-22         NaN         NaN
# 470          7        9503   2017-05-26         NaN         NaN
# 471        146        9507   2017-05-26         NaN         NaN
# 485        100        1211   2017-06-06         NaN         NaN
# 486        198        9504   2017-06-07         NaN         NaN
# 492        132        1211   2017-06-11         NaN         NaN
# 493        187        9503   2017-06-11         NaN         NaN
# 494         35        9505   2017-06-11         NaN         NaN
# 496        111        9502   2017-06-12         NaN         NaN
# 501        172        9502   2017-06-16         NaN         NaN
# 504        104        9503   2017-06-21         NaN         NaN
# 505        120        9503   2017-06-22         NaN         NaN
# 508         11        9508   2017-06-27         NaN         NaN
#
#          Service Facility Name Service Category         Region  Gender  \
# 0          PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 1      PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 3       PALOMAR MEDICAL CENTER      IP Hospital   North Inland    Male
# 6    CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 7    CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 11         ALVARADO PKWY INST       IP Hospital           East  Female
# 12     PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 14   CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 15         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 19        SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 24   CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 25         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 26     PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 29   CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 30         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 31         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 32     PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 38         ALVARADO PKWY INST       IP Hospital           East    Male
# 39     PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 40     PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 50         PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 53         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 59    SCRIPPS MERCY HEALTHCARE      IP Hospital        Central    Male
# 61         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 62     PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 66   CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 67        SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 73         PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 74     PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 75    SCRIPPS MERCY HEALTHCARE      IP Hospital        Central    Male
# ..                         ...              ...            ...     ...
# 418  SHARP MESA VISTA HOSP (A)      IP Hospital  North Central  Female
# 422    PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 425        PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 428        PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 430   SCRIPPS MERCY HEALTHCARE      IP Hospital        Central  Female
# 431        PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 434    PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 435  SHARP MESA VISTA HOSP (A)      IP Hospital  North Central    Male
# 436    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 437     PALOMAR MEDICAL CENTER      IP Hospital   North Inland  Female
# 441   OUT OF COUNTY HOSP ADULT      IP Hospital     No Address    Male
# 443        PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 447        PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 448    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 449       SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 453    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 460        UCSD MEDICAL CENTER      IP Hospital        Central    Male
# 461  SHARP MESA VISTA HOSP (A)      IP Hospital  North Central    Male
# 470    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 471     PALOMAR MEDICAL CENTER      IP Hospital   North Inland  Female
# 485  CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 486        UCSD MEDICAL CENTER      IP Hospital        Central  Female
# 492  CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 493    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 494       SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 496        PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 501        PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 504    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 505    PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 508          TRI-CITY HOSPITAL      IP Hospital  North Coastal    Male
#
#     Homeless Status
# 0          Homeless
# 1      Not Homeless
# 3      Not Homeless
# 6      Not Homeless
# 7          Homeless
# 11     Not Homeless
# 12     Not Homeless
# 14     Not Homeless
# 15     Not Homeless
# 19     Not Homeless
# 24     Not Homeless
# 25     Not Homeless
# 26     Not Homeless
# 29         Homeless
# 30     Not Homeless
# 31     Not Homeless
# 32     Not Homeless
# 38     Not Homeless
# 39     Not Homeless
# 40     Not Homeless
# 50     Not Homeless
# 53     Not Homeless
# 59     Not Homeless
# 61     Not Homeless
# 62     Not Homeless
# 66     Not Homeless
# 67         Homeless
# 73     Not Homeless
# 74         Homeless
# 75     Not Homeless
# ..              ...
# 418        Homeless
# 422    Not Homeless
# 425    Not Homeless
# 428    Not Homeless
# 430    Not Homeless
# 431    Not Homeless
# 434    Not Homeless
# 435        Homeless
# 436    Not Homeless
# 437        Homeless
# 441        Homeless
# 443    Not Homeless
# 447    Not Homeless
# 448    Not Homeless
# 449    Not Homeless
# 453    Not Homeless
# 460    Not Homeless
# 461    Not Homeless
# 470    Not Homeless
# 471    Not Homeless
# 485    Not Homeless
# 486    Not Homeless
# 492        Homeless
# 493    Not Homeless
# 494        Homeless
# 496    Not Homeless
# 501        Homeless
# 504    Not Homeless
# 505    Not Homeless
# 508    Not Homeless
#
# [176 rows x 10 columns]

# %% [markdown]
# # Addressing task of Creating a table that reflects the number of IP Hospital services in FY 2016-17 broken down by month and hospital name. Note any findings.

# %%
ax = hosp_frame['SubUnit ID'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number of unique amount of clients who had IP Hospital services in 16/17 by IP hospital ID")
ax.set_xlabel("SubUnit for IP Hospitals")
ax.set_ylabel("Unique Number of Clients")
# Out:
# Text(0, 0.5, 'Unique Number of Clients')

# %%
M=hosp_frame['SubUnit ID'].value_counts()

# %%
M.mean()
# Out:
# 16.0

# %% [markdown]
# # This first bar chart depicts the number of unique clients who had IP hospital services. Some clear observations is that PH Bayview hospital had significantly more clients than any other hospital. Also that the out of county hospital for adults had almost no clients serviced. The average number of clients serviced by hospital was found to be 16, so both PH bayview and PH paradise hospital could be seen as outliers. It is highly likely these hospitals are either in high density areas, or host high densities of psychiatric patients within the area.

# %%
path= (r'C:\Users\isaia\Downloads\Skills Assessment December 2020.xlsx')
client_services= pd.read_excel(path, sheet_name= 'Client Services in FY 2016-17')
client_services['month'] = client_services['Service Date'].astype(str).str[5:7]
client_services.month.value_counts().sort_index()
T=client_services.month.value_counts().sort_index()

# %%
T
# Out:
# 01    39
# 02    26
# 03    46
# 04    36
# 05    61
# 06    38
# 07    68
# 08    44
# 09    50
# 10    35
# 11    37
# 12    34
# Name: month, dtype: int64

# %%
T.mean() #Mean number of client services by month
# Out:
# 42.833333333333336

# %%
dx = client_services.month.value_counts().sort_index().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number of unique amount of clients who had IP Hospital services in 16/17 by Month")
ax.set_xlabel("SubUnit for IP Hospitals")
ax.set_ylabel("Unique Number of Clients by month")
# Out:
# Text(17.200000000000017, 0.5, 'Unique Number of Clients by month')

# %% [markdown]
# # This bar chart is a breakdown of the unique amount of clients who had IP hospital services by month. The average number of services was found to be approximately 43. This would leave me to believe that July and May are not only the busiest times but possibly outliers. This information would indicate that the hospitals would possibly need to allocate more labor during May and July. They can also possibly save labor during February.

# %% [markdown]
# # What percentage of unique clients that received IP Hospital services in FY 2016-17 were homeless?

# %%
hosp_frame
# Out:
#      Client ID  SubUnit ID Service Date  Unnamed: 3  Unnamed: 4  \
# 0           19        9502   2016-07-01         NaN         NaN
# 1          158        9503   2016-07-01         NaN         NaN
# 3           11        9507   2016-07-02         NaN         NaN
# 6            4        1211   2016-07-03         NaN         NaN
# 7          186        1211   2016-07-04         NaN         NaN
# 11          59        9501   2016-07-06         NaN        83.0
# 12          76        9503   2016-07-06         NaN         NaN
# 14         148        1211   2016-07-07         NaN         NaN
# 15         104        9502   2016-07-07         NaN         NaN
# 19          97        9505   2016-07-08         NaN         NaN
# 24         109        1211   2016-07-12         NaN         NaN
# 25          10        9502   2016-07-12         NaN         NaN
# 26         152        9503   2016-07-12         NaN         NaN
# 29         182        1211   2016-07-13         NaN         NaN
# 30         104        9502   2016-07-13         NaN         NaN
# 31          74        9502   2016-07-14         NaN         NaN
# 32         157        9503   2016-07-14         NaN         NaN
# 38         137        9501   2016-07-20         NaN         NaN
# 39           9        9503   2016-07-20         NaN         NaN
# 40          57        9503   2016-07-20         NaN         NaN
# 50         130        9502   2016-07-25         NaN         NaN
# 53          64        9502   2016-07-26         NaN         NaN
# 59          11        9506   2016-07-28         NaN         NaN
# 61          10        9502   2016-07-29         NaN         NaN
# 62          68        9503   2016-07-29         NaN         NaN
# 66          48        1211   2016-07-31         NaN         NaN
# 67         172        9505   2016-07-31         NaN         NaN
# 73           4        9502   2016-08-04         NaN         NaN
# 74          87        9503   2016-08-04         NaN         NaN
# 75          38        9506   2016-08-04         NaN         NaN
# ..         ...         ...          ...         ...         ...
# 418        172        9511   2017-05-02         NaN         NaN
# 422        120        9503   2017-05-03         NaN         NaN
# 425         64        9502   2017-05-04         NaN         NaN
# 428        111        9502   2017-05-06         NaN         NaN
# 430         76        9506   2017-05-08         NaN         NaN
# 431        104        9502   2017-05-09         NaN         NaN
# 434        157        9503   2017-05-10         NaN         NaN
# 435         73        9511   2017-05-10         NaN         NaN
# 436          7        9503   2017-05-11         NaN         NaN
# 437        156        9507   2017-05-11         NaN         NaN
# 441        184        9515   2017-05-13         NaN         NaN
# 443        104        9502   2017-05-16         NaN         NaN
# 447         44        9502   2017-05-17         NaN         NaN
# 448         10        9503   2017-05-17         NaN         NaN
# 449         69        9505   2017-05-17         NaN         NaN
# 453        187        9503   2017-05-18         NaN         NaN
# 460        100        9504   2017-05-22         NaN         NaN
# 461        185        9511   2017-05-22         NaN         NaN
# 470          7        9503   2017-05-26         NaN         NaN
# 471        146        9507   2017-05-26         NaN         NaN
# 485        100        1211   2017-06-06         NaN         NaN
# 486        198        9504   2017-06-07         NaN         NaN
# 492        132        1211   2017-06-11         NaN         NaN
# 493        187        9503   2017-06-11         NaN         NaN
# 494         35        9505   2017-06-11         NaN         NaN
# 496        111        9502   2017-06-12         NaN         NaN
# 501        172        9502   2017-06-16         NaN         NaN
# 504        104        9503   2017-06-21         NaN         NaN
# 505        120        9503   2017-06-22         NaN         NaN
# 508         11        9508   2017-06-27         NaN         NaN
#
#          Service Facility Name Service Category         Region  Gender  \
# 0          PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 1      PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 3       PALOMAR MEDICAL CENTER      IP Hospital   North Inland    Male
# 6    CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 7    CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 11         ALVARADO PKWY INST       IP Hospital           East  Female
# 12     PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 14   CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 15         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 19        SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 24   CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 25         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 26     PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 29   CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 30         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 31         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 32     PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 38         ALVARADO PKWY INST       IP Hospital           East    Male
# 39     PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 40     PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 50         PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 53         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 59    SCRIPPS MERCY HEALTHCARE      IP Hospital        Central    Male
# 61         PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 62     PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 66   CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 67        SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 73         PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 74     PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 75    SCRIPPS MERCY HEALTHCARE      IP Hospital        Central    Male
# ..                         ...              ...            ...     ...
# 418  SHARP MESA VISTA HOSP (A)      IP Hospital  North Central  Female
# 422    PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 425        PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 428        PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 430   SCRIPPS MERCY HEALTHCARE      IP Hospital        Central  Female
# 431        PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 434    PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 435  SHARP MESA VISTA HOSP (A)      IP Hospital  North Central    Male
# 436    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 437     PALOMAR MEDICAL CENTER      IP Hospital   North Inland  Female
# 441   OUT OF COUNTY HOSP ADULT      IP Hospital     No Address    Male
# 443        PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 447        PH BAYVIEW HOSPITAL      IP Hospital          South    Male
# 448    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 449       SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 453    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 460        UCSD MEDICAL CENTER      IP Hospital        Central    Male
# 461  SHARP MESA VISTA HOSP (A)      IP Hospital  North Central    Male
# 470    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 471     PALOMAR MEDICAL CENTER      IP Hospital   North Inland  Female
# 485  CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central    Male
# 486        UCSD MEDICAL CENTER      IP Hospital        Central  Female
# 492  CO SD CO PSYCH HOSP INPAT      IP Hospital  North Central  Female
# 493    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 494       SHARP GROSSMONT HOSP      IP Hospital           East  Female
# 496        PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 501        PH BAYVIEW HOSPITAL      IP Hospital          South  Female
# 504    PH PARADISE VALLEY HOSP      IP Hospital          South    Male
# 505    PH PARADISE VALLEY HOSP      IP Hospital          South  Female
# 508          TRI-CITY HOSPITAL      IP Hospital  North Coastal    Male
#
#     Homeless Status
# 0          Homeless
# 1      Not Homeless
# 3      Not Homeless
# 6      Not Homeless
# 7          Homeless
# 11     Not Homeless
# 12     Not Homeless
# 14     Not Homeless
# 15     Not Homeless
# 19     Not Homeless
# 24     Not Homeless
# 25     Not Homeless
# 26     Not Homeless
# 29         Homeless
# 30     Not Homeless
# 31     Not Homeless
# 32     Not Homeless
# 38     Not Homeless
# 39     Not Homeless
# 40     Not Homeless
# 50     Not Homeless
# 53     Not Homeless
# 59     Not Homeless
# 61     Not Homeless
# 62     Not Homeless
# 66     Not Homeless
# 67         Homeless
# 73     Not Homeless
# 74         Homeless
# 75     Not Homeless
# ..              ...
# 418        Homeless
# 422    Not Homeless
# 425    Not Homeless
# 428    Not Homeless
# 430    Not Homeless
# 431    Not Homeless
# 434    Not Homeless
# 435        Homeless
# 436    Not Homeless
# 437        Homeless
# 441        Homeless
# 443    Not Homeless
# 447    Not Homeless
# 448    Not Homeless
# 449    Not Homeless
# 453    Not Homeless
# 460    Not Homeless
# 461    Not Homeless
# 470    Not Homeless
# 471    Not Homeless
# 485    Not Homeless
# 486    Not Homeless
# 492        Homeless
# 493    Not Homeless
# 494        Homeless
# 496    Not Homeless
# 501        Homeless
# 504    Not Homeless
# 505    Not Homeless
# 508    Not Homeless
#
# [176 rows x 10 columns]

# %%
counts_hosp=hosp_frame['Homeless Status'].value_counts() 
#somehow need to do this as a count for homeless, likely by using hosp_frame['Homeless Status']

# %%
counts_hosp
# Out:
# Not Homeless    137
# Homeless         39
# Name: Homeless Status, dtype: int64

# %%
100 * counts_hosp / len(hosp_frame)
# Out:
# Not Homeless    77.840909
# Homeless        22.159091
# Name: Homeless Status, dtype: float64

# %% [markdown]
# # 22.16 percent of the unique clients who received IP hospital services were homeless. This can be seen as an important finding because it gives the exact amount of homeless these hospitals cater to. It would be interesting to find the percent homeless by hospital in order to observe which hospital is catering to homeless the most.
